# %% [markdown]
# # 07 - Model Training

# %% [markdown]
# ## 7.1 Set-Up

# %% [markdown]
# ### 7.1.1 - Initial Configuration

# %%
# logger.info("Setting up root by appending the parent to the sys...")
from jupyter_init import setup

setup()

from src_code.config import *

# %% [markdown]
# ### 7.1.2 - Setting up Logger

# %%
from notebooks.logging_config import setup_notebook_logging

logger, log_start, log_check, log_result = setup_notebook_logging(label="ENGINEERING")

log_start(print_to_console=True)
log_result("Logging configured.", print_to_console=True)
# Out:
# ================== Starting notebook: 07_model_training (Session 624) ==================
# [ENGINEERING RESULT] Logging configured.

# %% [markdown]
# ### 7.1.3 Imports & Configuration

# %%
import numpy as np
import pandas as pd

# ML
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_validate
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    classification_report,
    roc_auc_score,
    precision_recall_curve,
    confusion_matrix
)
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# Feature selection
from sklearn.feature_selection import VarianceThreshold
from sklearn.inspection import permutation_importance

# Imbalance handling
from sklearn.utils.class_weight import compute_class_weight

# Reproducibility
RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)

# %% [markdown]
# ### 7.1.4 Loading Dataset

# %%
log_check("Loading the dataset...")
import pandas as pd
import numpy as np
import seaborn as sns

# TRANSFORMED_DF = EXTRACTED_DATA_DIR / "train_labeled_features_partial.feather"
PREPROCESSED_DF = PREPROCESSED_DATA_DIR / "train_engineered.feather"

# ---- LOAD ----
df = pd.read_feather(PREPROCESSED_DF)

# %% [markdown]
# ## 7.2 Model Training

# %% [markdown]
# ### 7.2.1 Target & Column Separation

# %%
TARGET = "label"

# Drop identifiers & leakage-prone columns
DROP_COLS = [
    "commit",
    "repo",
    "filepath",
    "author_email",
    "datetime",
    "canonical_datetime",
]

df = df.drop(columns=DROP_COLS, errors="ignore")

# %% [markdown]
# ### 7.2.2 Embedding Handling (CodeBERT)
# Transformation on the embedding columns because machine learning models, especially traditional ones like Logistic Regression, Random Forests, or Gradient Boosting, cannot directly process a list or a NumPy array stored as a single entry (a cell) in a pandas DataFrame.
#
# The process is a necessary feature engineering step that converts the single embedding column into many separate numerical columns. This technique is often referred to as feature expansion or flattening the embedding vector.

# %%
def expand_embedding(df, col_name, prefix):
    emb = np.vstack(df[col_name].values)
    emb_df = pd.DataFrame(
        emb,
        index=df.index,
        columns=[f"{prefix}_{i}" for i in range(emb.shape[1])]
    )
    return emb_df

# %%
code_emb_df = expand_embedding(df, "code_embed", "code_emb")
msg_emb_df  = expand_embedding(df, "msg_embed", "msg_emb")

df = pd.concat(
    [df.drop(columns=["code_embed", "msg_embed"]), code_emb_df, msg_emb_df],
    axis=1
)

# %% [markdown]
# ### 7.2.3 Feature Type Identification

# %%
numeric_features = df.select_dtypes(include=["float64", "int64", "int8"]).columns.tolist()
numeric_features.remove(TARGET)
log_result(f"Numeric features: {numeric_features}", print_to_console=True)

categorical_features = df.select_dtypes(include=["category"]).columns.tolist()
log_result(f"Categorical features: {categorical_features}", print_to_console=True)

structured_features = [
    f for f in numeric_features
    if not f.startswith(("code_emb_", "msg_emb_"))
]
log_result(f"Structural features: {structured_features}", print_to_console=True)


embedding_features = [
    f for f in numeric_features
    if f.startswith(("code_emb_", "msg_emb_"))
]
log_result(f"embedding_features: {embedding_features}", print_to_console=True)
# Out:
# [ENGINEERING RESULT] Numeric features: ['author_exp_pre', 'author_recent_activity_pre', 'loc_added', 'loc_deleted', 'files_changed', 'hunks_count', 'msg_len', 'has_fix_kw', 'has_bug_kw', 'ast_delta', 'complexity_delta', 'max_func_change', 'time_since_last_change', 'todo', 'fixme', 'try', 'except', 'raise', 'recent_churn', 'recent_churn_winsorized', 'loc_churn_ratio', 'activity_per_exp', 'extreme_churn_flag', 'loc_added_bucket_cat', 'line_token_total', 'todo_ratio', 'fixme_ratio', 'try_ratio', 'except_ratio', 'raise_ratio', 'loc_added_x_loc_deleted', 'loc_added_x_hunks_count', 'loc_deleted_x_hunks_count', 'code_emb_0', 'code_emb_1', 'code_emb_2', 'code_emb_3', 'code_emb_4', 'code_emb_5', 'code_emb_6', 'code_emb_7', 'code_emb_8', 'code_emb_9', 'code_emb_10', 'code_emb_11', 'code_emb_12', 'code_emb_13', 'code_emb_14', 'code_emb_15', 'code_emb_16', 'code_emb_17', 'code_emb_18', 'code_emb_19', 'code_emb_20', 'code_emb_21', 'code_emb_22', 'code_emb_23', 'code_emb_24', 'code_emb_25', 'code_emb_26', 'code_emb_27', 'code_emb_28', 'code_emb_29', 'code_emb_30', 'code_emb_31', 'code_emb_32', 'code_emb_33', 'code_emb_34', 'code_emb_35', 'code_emb_36', 'code_emb_37', 'code_emb_38', 'code_emb_39', 'code_emb_40', 'code_emb_41', 'code_emb_42', 'code_emb_43', 'code_emb_44', 'code_emb_45', 'code_emb_46', 'code_emb_47', 'code_emb_48', 'code_emb_49', 'code_emb_50', 'code_emb_51', 'code_emb_52', 'code_emb_53', 'code_emb_54', 'code_emb_55', 'code_emb_56', 'code_emb_57', 'code_emb_58', 'code_emb_59', 'code_emb_60', 'code_emb_61', 'code_emb_62', 'code_emb_63', 'code_emb_64', 'code_emb_65', 'code_emb_66', 'code_emb_67', 'code_emb_68', 'code_emb_69', 'code_emb_70', 'code_emb_71', 'code_emb_72', 'code_emb_73', 'code_emb_74', 'code_emb_75', 'code_emb_76', 'code_emb_77', 'code_emb_78', 'code_emb_79', 'code_emb_80', 'code_emb_81', 'code_emb_82', 'code_emb_83', 'code_emb_84', 'code_emb_85', 'code_emb_86', 'code_emb_87', 'code_emb_88', 'code_emb_89', 'code_emb_90', 'code_emb_91', 'code_emb_92', 'code_emb_93', 'code_emb_94', 'code_emb_95', 'code_emb_96', 'code_emb_97', 'code_emb_98', 'code_emb_99', 'code_emb_100', 'code_emb_101', 'code_emb_102', 'code_emb_103', 'code_emb_104', 'code_emb_105', 'code_emb_106', 'code_emb_107', 'code_emb_108', 'code_emb_109', 'code_emb_110', 'code_emb_111', 'code_emb_112', 'code_emb_113', 'code_emb_114', 'code_emb_115', 'code_emb_116', 'code_emb_117', 'code_emb_118', 'code_emb_119', 'code_emb_120', 'code_emb_121', 'code_emb_122', 'code_emb_123', 'code_emb_124', 'code_emb_125', 'code_emb_126', 'code_emb_127', 'code_emb_128', 'code_emb_129', 'code_emb_130', 'code_emb_131', 'code_emb_132', 'code_emb_133', 'code_emb_134', 'code_emb_135', 'code_emb_136', 'code_emb_137', 'code_emb_138', 'code_emb_139', 'code_emb_140', 'code_emb_141', 'code_emb_142', 'code_emb_143', 'code_emb_144', 'code_emb_145', 'code_emb_146', 'code_emb_147', 'code_emb_148', 'code_emb_149', 'code_emb_150', 'code_emb_151', 'code_emb_152', 'code_emb_153', 'code_emb_154', 'code_emb_155', 'code_emb_156', 'code_emb_157', 'code_emb_158', 'code_emb_159', 'code_emb_160', 'code_emb_161', 'code_emb_162', 'code_emb_163', 'code_emb_164', 'code_emb_165', 'code_emb_166', 'code_emb_167', 'code_emb_168', 'code_emb_169', 'code_emb_170', 'code_emb_171', 'code_emb_172', 'code_emb_173', 'code_emb_174', 'code_emb_175', 'code_emb_176', 'code_emb_177', 'code_emb_178', 'code_emb_179', 'code_emb_180', 'code_emb_181', 'code_emb_182', 'code_emb_183', 'code_emb_184', 'code_emb_185', 'code_emb_186', 'code_emb_187', 'code_emb_188', 'code_emb_189', 'code_emb_190', 'code_emb_191', 'code_emb_192', 'code_emb_193', 'code_emb_194', 'code_emb_195', 'code_emb_196', 'code_emb_197', 'code_emb_198', 'code_emb_199', 'code_emb_200', 'code_emb_201', 'code_emb_202', 'code_emb_203', 'code_emb_204', 'code_emb_205', 'code_emb_206', 'code_emb_207', 'code_emb_208', 'code_emb_209', 'code_emb_210', 'code_emb_211', 'code_emb_212', 'code_emb_213', 'code_emb_214', 'code_emb_215', 'code_emb_216', 'code_emb_217', 'code_emb_ ...
# [ENGINEERING RESULT] Categorical features: ['loc_added_bucket']
# [ENGINEERING RESULT] Structural features: ['author_exp_pre', 'author_recent_activity_pre', 'loc_added', 'loc_deleted', 'files_changed', 'hunks_count', 'msg_len', 'has_fix_kw', 'has_bug_kw', 'ast_delta', 'complexity_delta', 'max_func_change', 'time_since_last_change', 'todo', 'fixme', 'try', 'except', 'raise', 'recent_churn', 'recent_churn_winsorized', 'loc_churn_ratio', 'activity_per_exp', 'extreme_churn_flag', 'loc_added_bucket_cat', 'line_token_total', 'todo_ratio', 'fixme_ratio', 'try_ratio', 'except_ratio', 'raise_ratio', 'loc_added_x_loc_deleted', 'loc_added_x_hunks_count', 'loc_deleted_x_hunks_count']
# [ENGINEERING RESULT] embedding_features: ['code_emb_0', 'code_emb_1', 'code_emb_2', 'code_emb_3', 'code_emb_4', 'code_emb_5', 'code_emb_6', 'code_emb_7', 'code_emb_8', 'code_emb_9', 'code_emb_10', 'code_emb_11', 'code_emb_12', 'code_emb_13', 'code_emb_14', 'code_emb_15', 'code_emb_16', 'code_emb_17', 'code_emb_18', 'code_emb_19', 'code_emb_20', 'code_emb_21', 'code_emb_22', 'code_emb_23', 'code_emb_24', 'code_emb_25', 'code_emb_26', 'code_emb_27', 'code_emb_28', 'code_emb_29', 'code_emb_30', 'code_emb_31', 'code_emb_32', 'code_emb_33', 'code_emb_34', 'code_emb_35', 'code_emb_36', 'code_emb_37', 'code_emb_38', 'code_emb_39', 'code_emb_40', 'code_emb_41', 'code_emb_42', 'code_emb_43', 'code_emb_44', 'code_emb_45', 'code_emb_46', 'code_emb_47', 'code_emb_48', 'code_emb_49', 'code_emb_50', 'code_emb_51', 'code_emb_52', 'code_emb_53', 'code_emb_54', 'code_emb_55', 'code_emb_56', 'code_emb_57', 'code_emb_58', 'code_emb_59', 'code_emb_60', 'code_emb_61', 'code_emb_62', 'code_emb_63', 'code_emb_64', 'code_emb_65', 'code_emb_66', 'code_emb_67', 'code_emb_68', 'code_emb_69', 'code_emb_70', 'code_emb_71', 'code_emb_72', 'code_emb_73', 'code_emb_74', 'code_emb_75', 'code_emb_76', 'code_emb_77', 'code_emb_78', 'code_emb_79', 'code_emb_80', 'code_emb_81', 'code_emb_82', 'code_emb_83', 'code_emb_84', 'code_emb_85', 'code_emb_86', 'code_emb_87', 'code_emb_88', 'code_emb_89', 'code_emb_90', 'code_emb_91', 'code_emb_92', 'code_emb_93', 'code_emb_94', 'code_emb_95', 'code_emb_96', 'code_emb_97', 'code_emb_98', 'code_emb_99', 'code_emb_100', 'code_emb_101', 'code_emb_102', 'code_emb_103', 'code_emb_104', 'code_emb_105', 'code_emb_106', 'code_emb_107', 'code_emb_108', 'code_emb_109', 'code_emb_110', 'code_emb_111', 'code_emb_112', 'code_emb_113', 'code_emb_114', 'code_emb_115', 'code_emb_116', 'code_emb_117', 'code_emb_118', 'code_emb_119', 'code_emb_120', 'code_emb_121', 'code_emb_122', 'code_emb_123', 'code_emb_124', 'code_emb_125', 'code_emb_126', 'code_emb_127', 'code_emb_128', 'code_emb_129', 'code_emb_130', 'code_emb_131', 'code_emb_132', 'code_emb_133', 'code_emb_134', 'code_emb_135', 'code_emb_136', 'code_emb_137', 'code_emb_138', 'code_emb_139', 'code_emb_140', 'code_emb_141', 'code_emb_142', 'code_emb_143', 'code_emb_144', 'code_emb_145', 'code_emb_146', 'code_emb_147', 'code_emb_148', 'code_emb_149', 'code_emb_150', 'code_emb_151', 'code_emb_152', 'code_emb_153', 'code_emb_154', 'code_emb_155', 'code_emb_156', 'code_emb_157', 'code_emb_158', 'code_emb_159', 'code_emb_160', 'code_emb_161', 'code_emb_162', 'code_emb_163', 'code_emb_164', 'code_emb_165', 'code_emb_166', 'code_emb_167', 'code_emb_168', 'code_emb_169', 'code_emb_170', 'code_emb_171', 'code_emb_172', 'code_emb_173', 'code_emb_174', 'code_emb_175', 'code_emb_176', 'code_emb_177', 'code_emb_178', 'code_emb_179', 'code_emb_180', 'code_emb_181', 'code_emb_182', 'code_emb_183', 'code_emb_184', 'code_emb_185', 'code_emb_186', 'code_emb_187', 'code_emb_188', 'code_emb_189', 'code_emb_190', 'code_emb_191', 'code_emb_192', 'code_emb_193', 'code_emb_194', 'code_emb_195', 'code_emb_196', 'code_emb_197', 'code_emb_198', 'code_emb_199', 'code_emb_200', 'code_emb_201', 'code_emb_202', 'code_emb_203', 'code_emb_204', 'code_emb_205', 'code_emb_206', 'code_emb_207', 'code_emb_208', 'code_emb_209', 'code_emb_210', 'code_emb_211', 'code_emb_212', 'code_emb_213', 'code_emb_214', 'code_emb_215', 'code_emb_216', 'code_emb_217', 'code_emb_218', 'code_emb_219', 'code_emb_220', 'code_emb_221', 'code_emb_222', 'code_emb_223', 'code_emb_224', 'code_emb_225', 'code_emb_226', 'code_emb_227', 'code_emb_228', 'code_emb_229', 'code_emb_230', 'code_emb_231', 'code_emb_232', 'code_emb_233', 'code_emb_234', 'code_emb_235', 'code_emb_236', 'code_emb_237', 'code_emb_238', 'code_emb_239', 'code_emb_240', 'code_emb_241', 'code_emb_242', 'code_emb_243', 'code_emb_244', 'code_emb_245', 'code_emb_246', 'code_emb_247', 'code_emb_248', 'code_emb_249', 'code_emb_250', 'code_emb_251', 'code_emb_252', 'code_emb_253', 'cod ...

# %% [markdown]
# ### 7.2.4 Train / Test Split (Stratified)

# %%
X = df.drop(columns=[TARGET])
y = df[TARGET]

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2,
    stratify=y,
    random_state=RANDOM_STATE
)

# %% [markdown]
# ### 7.2.5 Preprocessing Pipeline

# %% [markdown]
# Design choices (aligned with the EDA):
# - No scaling for trees
# - Remove zero-variance features
# - Keep engineered features (selection later)

# %%
from sklearn.decomposition import PCA


numeric_transformer = Pipeline(steps=[
    ("var_thresh", VarianceThreshold(threshold=0.0))
])

embedding_transformer = Pipeline(steps=[
    ("pca", PCA(n_components=100, random_state=RANDOM_STATE))
])

# preprocessor = ColumnTransformer(
#     transformers=[
#         ("num", numeric_transformer, numeric_features),
#     ],
#     remainder="drop"
# )
preprocessor = ColumnTransformer(
    transformers=[
        ("struct", "passthrough", structured_features),
        ("embed", embedding_transformer, embedding_features),
    ],
    remainder="drop"
)

# %% [markdown]
# ### 7.2.5 Baseline Random Forest Model

# %%
rf = RandomForestClassifier(
    n_estimators=50,
    max_depth=None,
    min_samples_leaf=2,
    random_state=RANDOM_STATE,
    # class_weight=CLASS_WEIGHT,
    n_jobs=1              # 🔴 IMPORTANT
)

model = Pipeline(steps=[
    ("preprocess", preprocessor),
    ("rf", rf)
])

# %% [markdown]
# ### 7.2.6 Cross-Validation (Primary Evaluation)

# %%
cv = StratifiedKFold(n_splits=2, shuffle=True, random_state=RANDOM_STATE)

scoring = {
    "roc_auc": "roc_auc",
    "f1": "f1",
    "precision": "precision",
    "recall": "recall"
}

cv_results = cross_validate(
    model,
    X_train,
    y_train,
    cv=cv,
    scoring=scoring,
    n_jobs=2
)

pd.DataFrame(cv_results).mean()

# %% [markdown]
# ### 7.2.7 Final Training & Test Evaluation

# %%
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
y_proba = model.predict_proba(X_test)[:, 1]

print(classification_report(y_test, y_pred))
print("ROC-AUC:", roc_auc_score(y_test, y_proba))

# %% [markdown]
# ### 7.2.8 Feature Importance (Permutation-Based)
#
# Critical due to correlated engineered features

# %%
perm = permutation_importance(
    model,
    X_test,
    y_test,
    n_repeats=2,
    random_state=RANDOM_STATE,
    n_jobs=2
)

importances = pd.Series(
    perm.importances_mean,
    index=model.named_steps["preprocess"].get_feature_names_out()
).sort_values(ascending=False)

importances.head(20)

# %% [markdown]
# ### 7.2.9 Feature Subset Refinement (Optional Iteration)
# (Re-run steps 8–11 using reduced feature set)

# %%
TOP_K = 100
top_features = importances.head(TOP_K).index.tolist()

X_train_reduced = X_train[top_features]
X_test_reduced  = X_test[top_features]
