# %% [markdown]
# # 01 - Quick Glimpse on Raw Data

# %% [markdown]
# ## Setting up Project Directory

# %%
from jupyter_init import setup
setup()

# %% [markdown]
# ## Loading Data

# %%
from src_code.config import DEFECTORS_DIR
import pandas as pd


RAW_DATASET_FILE = DEFECTORS_DIR / "line_bug_prediction_splits/time/train.feather"

df = pd.read_feather(RAW_DATASET_FILE)

# %% [markdown]
# ## Repo Proportion

# %%
df.dtypes
print(df['repo'].value_counts(normalize=True))
# Out:
# repo
# ansible                  0.231031
# sentry                   0.172402
# core                     0.157205
# pandas                   0.078314
# ray                      0.065852
# django                   0.059487
# lightning                0.043724
# airflow                  0.043119
# cpython                  0.038205
# scikit-learn             0.026099
# celery                   0.018638
# spaCy                    0.012758
# poetry                   0.009284
# localstack               0.007148
# transformers             0.006668
# openpilot                0.005702
# numpy                    0.005227
# yolov5                   0.004386
# redash                   0.003884
# jax                      0.003566
# black                    0.002390
# scrapy                   0.002239
# django-rest-framework    0.002174
# pipenv                   0.000491
# freqtrade                0.000005
# Name: proportion, dtype: float64
