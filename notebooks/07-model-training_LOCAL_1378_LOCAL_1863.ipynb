# %% [markdown]
# # 07 - Model Training

# %% [markdown]
# ## 7.1 Set-Up

# %% [markdown]
# ### 7.1.1 - Logger

# %%
from logging_config import LOG_PATH, NotebookLogger

# logger, log_start, log_check, log_result = setup_notebook_logging(label="ENGINEERING")
logger = NotebookLogger(label="TRAIN", notebook_name=None, file_log_path=LOG_PATH)

logger.log_start(print_to_console=True)
logger.log_result("Logging configured.", print_to_console=True)
# Out:
# ================== Starting notebook: 07-model-training_LOCAL_1378 (Session 260) ==================
# [TRAIN RESULT] Logging configured.

# %% [markdown]
# ### 7.1.2 - Project Root

# %%
# logger.info("Setting up root by appending the parent to the sys...")
from jupyter_init import setup

setup()

# %% [markdown]
# ### 7.1.3 Libs

# %%
from notebooks.juputils import display_func
from src_code.config import *


# --- local modules ---

from src_code.ml_pipeline.df_utils import load_df

from main_config import setup as main_setup
from src_code.ml_pipeline.feature_config import DROP_COLS
from src_code.ml_pipeline.training.utils import drop_cols
from src_code.ml_pipeline.training.utils import analyze_features

from main_config import RANDOM_STATE
from notebooks.constants import TARGET
from main_config import TEST_SPLIT

from src_code.ml_pipeline.models import RFWrapper
from src_code.ml_pipeline.pipelines import RFPipelineWrapper
from src_code.ml_pipeline.validations import CVWrapper
from src_code.ml_pipeline.validations import CVWrapper
from src_code.ml_pipeline.training.train import fit_model
from src_code.ml_pipeline.training.train import split_train_test
from src_code.ml_pipeline.training.tuning import RFTuningWrapper
from src_code.ml_pipeline.training.train import check_single_infer
from src_code.ml_pipeline.feature_importance import PFIWrapper
from src_code.ml_pipeline.df_utils import save_model

main_setup()

# %% [markdown]
# ### 7.1.4 Loading Dataset

# %%
logger.log_check("Loading the dataset...")

# TRANSFORMED_DF = EXTRACTED_DATA_DIR / "train_labeled_features_partial.feather"
# PREPROCESSED_DF = PROCESSED_DATA_DIR / "train_engineered.feather"
DF_PATH = ENGINEERING_MAPPINGS['train']['output']

# ---- LOAD ----
# df = pd.read_feather(DF_PATH)
# df.describe()

df = load_df(DF_PATH, logger=logger)
df.describe()
# Out:
# [TRAIN CHECK] Loading the dataset...
# [TRAIN CHECK] Loading the dataset...
# [TRAIN RESULT] Loaded dataframe with 139545 rows and 103 columns
#        author_exp_pre  author_recent_activity_pre      loc_added  \
# count   139545.000000               139545.000000  139545.000000
# mean         4.432032                    2.913750       2.982764
# std          2.113777                    1.577641       1.749270
# min          0.000000                    0.000000       0.000000
# 25%          2.995732                    1.791759       1.386294
# 50%          4.875197                    3.091042       3.135494
# 75%          6.167516                    4.219508       4.543295
# max          7.058328                    5.081404       5.433722
#
#          loc_deleted  files_changed    hunks_count        msg_len  \
# count  139545.000000  139545.000000  139545.000000  139545.000000
# mean        3.539947       1.950455       3.151959       4.540631
# std         1.671126       1.057575       1.409620       0.859233
# min         0.000000       0.000000       0.000000       0.693147
# 25%         2.302585       1.098612       1.945910       3.912023
# 50%         3.806662       1.791759       3.135494       4.330733
# 75%         4.941642       2.833213       4.343805       5.241747
# max         5.814131       3.637586       5.204007       5.985195
#
#            ast_delta  complexity_delta  max_func_change  \
# count  139545.000000     139545.000000    139545.000000
# mean        2.134896          0.625291         3.436580
# std         2.288227          0.862086         1.841744
# min         0.000000          0.000000         0.000000
# 25%         0.000000          0.000000         2.772589
# 50%         1.098612          0.000000         4.025352
# 75%         4.564348          1.386294         4.762174
# max         5.474369          2.140066         5.592851
#
#        time_since_last_change   recent_churn           todo          fixme  \
# count           139545.000000  139545.000000  139545.000000  139545.000000
# mean                 6.804231       6.250559       0.060705       0.012647
# std                  2.683010       3.207311       0.261651       0.135984
# min                  0.000000       0.000000       0.000000       0.000000
# 25%                  5.605802       4.644391       0.000000       0.000000
# 50%                  7.465083       7.164720       0.000000       0.000000
# 75%                  8.810460       8.837246       0.000000       0.000000
# max                  9.702105       9.744433       4.691348       3.970292
#
#                  try         except          raise    code_emb_0  \
# count  139545.000000  139545.000000  139545.000000  1.395450e+05
# mean        0.544129       0.263748       0.195102 -4.223387e-15
# std         1.059338       0.703362       0.567292  2.219653e+00
# min         0.000000       0.000000       0.000000 -3.425968e+00
# 25%         0.000000       0.000000       0.000000 -6.762461e-01
# 50%         0.000000       0.000000       0.000000 -2.655769e-01
# 75%         0.693147       0.000000       0.000000  2.085006e-01
# max        12.435612       9.041330       7.526179  1.615720e+01
#
#          code_emb_1    code_emb_2    code_emb_3    code_emb_4    code_emb_5  \
# count  1.395450e+05  1.395450e+05  1.395450e+05  1.395450e+05  1.395450e+05
# mean  -7.299682e-16  1.538147e-15  7.821087e-17 -2.607029e-17  2.313738e-16
# std    1.448152e+00  1.023242e+00  7.669118e-01  6.201064e-01  5.688169e-01
# min   -5.010717e+00 -5.258590e+00 -3.103425e+00 -2.142570e+00 -2.911938e+00
# 25%   -1.025519e+00 -7.850446e-01 -4.953535e-01 -4.271986e-01 -2.145677e-01
# 50%   -9.212816e-02 -9.274639e-02 -1.490366e-01 -7.647201e-02  6.136290e-02
# 75%    9.974107e-01  7.035160e-01  4.145890e-01  3.604159e-01  2.961761e-01
# max    5.846751e+00  4.084592e+00  3.901235e+00  2.935733e+00  1.421278e+00
#
#          code_emb_6    code_emb_7  ...    msg_emb_34    msg_emb_35  \
# count  1.395450e+05  1.395450e+05  ...  1.395450e+05  1.395450e+05
# mean  -5.768052e-16  2.437572e-15  ...  1.140575e-16  4.537860e-16
# std    4.886902e-01  3.937198e-01  ...  2.104797e-01  2.041841e-01
# min   -2.139680e+00 -2.444615e+00  ... -9.364891e-01 -1.056244e+00
# 25%   -2.887873e-01 -2.488683e-01  ... -1.351221e-01 -1.290165e-01
# 50%    2.407541e-02 -1.038398e-02  ... -3.622844e-04 -5.184692e-04
# 75%    2.742740e-01  2.392909e-01  ...  1.335562e-01  1.313729e-01
# max    2.155233e+00  1.403595e+00  ...  1.154362e+00  1.319173e+00
#
#          msg_emb_36    msg_emb_37    msg_emb_38    msg_emb_39    msg_emb_40  \
# count  1.395450e+05  1.395450e+05  1.395450e+05  1.395450e+05  1.395450e+05
# mean   1.547924e-17  6.150959e-17  8.951988e-16  1.466454e-16  4.252716e-16
# std    2.027971e-01  2.001190e-01  1.964164e-01  1.941571e-01  1.892906e-01
# min   -1.008676e+00 -1.142868e+00 -1.119048e+00 -9.300965e-01 -1.063362e+00
# 25%   -1.292397e-01 -1.285220e-01 -1.269535e-01 -1.172182e-01 -1.226275e-01
# 50%    3.640943e-03 -5.002660e-03 -7.044206e-03  3.589629e-03 -2.091944e-04
# 75%    1.255679e-01  1.247857e-01  1.195289e-01  1.273497e-01  1.216240e-01
# max    9.797174e-01  9.108456e-01  1.581407e+00  1.092264e+00  1.183203e+00
#
#          msg_emb_41    msg_emb_42    msg_emb_43    msg_emb_44          label  \
# count  1.395450e+05  1.395450e+05  1.395450e+05  1.395450e+05  139545.000000
# mean  -1.162674e-15 -1.189457e-15  1.792333e-16  2.338179e-16       0.461149
# std    1.881260e-01  1.853564e-01  1.834569e-01  1.833782e-01       0.498490
# min   -1.023447e+00 -9.268058e-01 -1.955976e+00 -1.077711e+00       0.000000
# 25%   -1.173649e-01 -1.187762e-01 -1.144729e-01 -1.209108e-01       0.000000
# 50%    8.205552e-04 -3.348134e-04 -1.941068e-03 -7.910400e-04       0.000000
# 75%    1.181880e-01  1.164196e-01  1.170017e-01  1.198320e-01       1.000000
# max    9.005868e-01  1.503891e+00  1.156565e+00  9.212782e-01       1.000000
#
#           has_fix_kw     has_bug_kw  loc_churn_ratio  activity_per_exp  \
# count  139545.000000  139545.000000    139545.000000     139545.000000
# mean        0.304927       0.057279         0.638588          0.500729
# std         0.460378       0.232376         0.407399          0.223706
# min         0.000000       0.000000         0.000000          0.000000
# 25%         0.000000       0.000000         0.422698          0.405511
# 50%         0.000000       0.000000         0.677650          0.551684
# 75%         1.000000       0.000000         0.798161          0.655915
# max         1.000000       1.000000         5.433722          0.835564
#
#        line_token_total     todo_ratio    fixme_ratio      try_ratio  \
# count     139545.000000  139545.000000  139545.000000  139545.000000
# mean           1.076331       0.013312       0.004803       0.116986
# std            1.945555       0.062077       0.050329       0.291973
# min            0.000000       0.000000       0.000000       0.000000
# 25%            0.000000       0.000000       0.000000       0.000000
# 50%            0.000000       0.000000       0.000000       0.000000
# 75%            1.386294       0.000000       0.000000       0.165902
# max           33.835868       1.098612       1.098612       5.883322
#
#         except_ratio    raise_ratio  loc_added_x_loc_deleted  \
# count  139545.000000  139545.000000            139545.000000
# mean        0.053682       0.036393                12.748085
# std         0.156061       0.102202                10.214727
# min         0.000000       0.000000                 0.000000
# 25%         0.000000       0.000000                 3.131822
# 50%         0.000000       0.000000                11.297390
# 75%         0.000000       0.000000                21.315890
# max         2.639057       2.197225                31.592369
#
#        loc_added_x_hunks_count  loc_deleted_x_hunks_count
# count            139545.000000              139545.000000
# mean                 11.486308                  13.122828
# std                   9.270532                   9.355984
# min                   0.000000                   0.000000
# 25%                   2.817885                   4.651874
# 50%                   9.729218                  12.030912
# 75%                  18.920826                  20.781406
# max                  28.277126                  30.256774
#
# [8 rows x 86 columns]

# %% [markdown]
# ## 7.2 Model Training

# %% [markdown]
# ### 7.2.1 Target & Column Separation

# %%
display_func(drop_cols)
# Out:
# <style>
# .jp-CodeCell .highlight,
# .output pre,
# .output code {
#     background-color: #111111 !important;
#     color: #94d4d4 !important;
# }
# </style>
# def drop_cols(
#     df: pd.DataFrame, cols: Iterable[str], logger: NotebookLogger = DEF_NOTEBOOK_LOGGER
# ):
#     logger.log_check("Dropping the specified columns...")
#
#     start_cols = set(df.columns)
#
#     df = df.drop(columns=cols, errors="ignore")
#
#     end_cols = set(df.columns)
#
#     logger.log_result("Dropping completed.")
#     logger.log_result(f"Columns dropped: {len(start_cols - end_cols)}")
#     logger.log_result(f"Columns remaining: {len(end_cols)}")
#     return df

# %%
# TARGET = "label"

# # Drop identifiers & leakage-prone columns
# DROP_COLS = [
#     "commit",
#     "repo",
#     "filepath",
#     "author_email",
#     "datetime",
#     "canonical_datetime",
#     "content",
#     "methods",
#     "lines",
#     "files_changed",
#     "loc_added_bucket"
# ]

# df = df.drop(columns=DROP_COLS, errors="ignore")
# my_list = df.columns.values.tolist()
# print(my_list)


df = drop_cols(df=df, cols=DROP_COLS, logger=logger)
# Out:
# [TRAIN CHECK] Dropping the specified columns...
# [TRAIN RESULT] Dropping completed.
# [TRAIN RESULT] Columns dropped: 10
# [TRAIN RESULT] Columns remaining: 93

# %% [markdown]
# ### 7.2.2 Embedding Handling (CodeBERT)
# Transformation on the embedding columns because machine learning models, especially traditional ones like Logistic Regression, Random Forests, or Gradient Boosting, cannot directly process a list or a NumPy array stored as a single entry (a cell) in a pandas DataFrame.
#
# The process is a necessary feature engineering step that converts the single embedding column into many separate numerical columns. This technique is often referred to as feature expansion or flattening the embedding vector.

# %% [markdown]
# ### 7.2.3 Feature Type Identification

# %%
display_func(analyze_features)
# Out:
# <style>
# .jp-CodeCell .highlight,
# .output pre,
# .output code {
#     background-color: #111111 !important;
#     color: #94d4d4 !important;
# }
# </style>
# def analyze_features(
#     df: pd.DataFrame, target: str, logger: NotebookLogger = DEF_NOTEBOOK_LOGGER
# ):
#     logger.log_check("Starting df feature analysis...")
#     # numeric_features = df.select_dtypes(include=["float64", "int64", "int8"]).columns.tolist()
#
#     # numeric_features = df.select_dtypes(include="number").columns.tolist()
#     numeric_features = df.select_dtypes(include=["number", "bool"]).columns.tolist()
#
#     numeric_features.remove(target)
#     logger.log_result(f"Numeric features: {numeric_features}", print_to_console=True)
#
#     categorical_features = df.select_dtypes(include=["category"]).columns.tolist()
#     logger.log_result(
#         f"Categorical features: {categorical_features}", print_to_console=True
#     )
#
#     structured_features = [
#         f for f in numeric_features if not f.startswith(("code_emb_", "msg_emb_"))
#     ]
#     logger.log_result(
#         f"Structural features: {structured_features}", print_to_console=True
#     )
#     logger.log_result(len(structured_features), print_to_console=True)
#
#     embedding_features = [
#         f for f in numeric_features if f.startswith(("code_emb_", "msg_emb_"))
#     ]
#     logger.log_result(
#         f"embedding_features: {embedding_features}", print_to_console=True
#     )
#
#     logger.log_result("Analysis completed.")

# %%
analyze_features(df=df, target=TARGET, logger=logger)

# numeric_features = df.select_dtypes(include=["float64", "int64", "int8"]).columns.tolist()
# numeric_features.remove(TARGET)
# logger.log_result(f"Numeric features: {numeric_features}", print_to_console=True)

# categorical_features = df.select_dtypes(include=["category"]).columns.tolist()
# logger.log_result(f"Categorical features: {categorical_features}", print_to_console=True)

# structured_features = [
#     f for f in numeric_features
#     if not f.startswith(("code_emb_", "msg_emb_"))
# ]
# logger.log_result(f"Structural features: {structured_features}", print_to_console=True)
# logger.log_result(len(structured_features), print_to_console=True)


# embedding_features = [
#     f for f in numeric_features
#     if f.startswith(("code_emb_", "msg_emb_"))
# ]
# logger.log_result(f"embedding_features: {embedding_features}", print_to_console=True)
# Out:
# [TRAIN CHECK] Starting df feature analysis...
# [TRAIN RESULT] Numeric features: ['author_exp_pre', 'author_recent_activity_pre', 'loc_added', 'loc_deleted', 'hunks_count', 'msg_len', 'ast_delta', 'complexity_delta', 'max_func_change', 'time_since_last_change', 'recent_churn', 'todo', 'fixme', 'try', 'except', 'raise', 'code_emb_0', 'code_emb_1', 'code_emb_2', 'code_emb_3', 'code_emb_4', 'code_emb_5', 'code_emb_6', 'code_emb_7', 'code_emb_8', 'code_emb_9', 'msg_emb_0', 'msg_emb_1', 'msg_emb_2', 'msg_emb_3', 'msg_emb_4', 'msg_emb_5', 'msg_emb_6', 'msg_emb_7', 'msg_emb_8', 'msg_emb_9', 'msg_emb_10', 'msg_emb_11', 'msg_emb_12', 'msg_emb_13', 'msg_emb_14', 'msg_emb_15', 'msg_emb_16', 'msg_emb_17', 'msg_emb_18', 'msg_emb_19', 'msg_emb_20', 'msg_emb_21', 'msg_emb_22', 'msg_emb_23', 'msg_emb_24', 'msg_emb_25', 'msg_emb_26', 'msg_emb_27', 'msg_emb_28', 'msg_emb_29', 'msg_emb_30', 'msg_emb_31', 'msg_emb_32', 'msg_emb_33', 'msg_emb_34', 'msg_emb_35', 'msg_emb_36', 'msg_emb_37', 'msg_emb_38', 'msg_emb_39', 'msg_emb_40', 'msg_emb_41', 'msg_emb_42', 'msg_emb_43', 'msg_emb_44', 'has_fix_kw', 'has_bug_kw', 'loc_churn_ratio', 'activity_per_exp', 'loc_added_bucket_very_small', 'loc_added_bucket_small', 'loc_added_bucket_medium', 'loc_added_bucket_large', 'loc_added_bucket_very_large', 'author_exp_pre_bucket_junior', 'author_exp_pre_bucket_mid', 'author_exp_pre_bucket_senior', 'line_token_total', 'todo_ratio', 'fixme_ratio', 'try_ratio', 'except_ratio', 'raise_ratio', 'loc_added_x_loc_deleted', 'loc_added_x_hunks_count', 'loc_deleted_x_hunks_count']
# [TRAIN RESULT] Categorical features: []
# [TRAIN RESULT] Structural features: ['author_exp_pre', 'author_recent_activity_pre', 'loc_added', 'loc_deleted', 'hunks_count', 'msg_len', 'ast_delta', 'complexity_delta', 'max_func_change', 'time_since_last_change', 'recent_churn', 'todo', 'fixme', 'try', 'except', 'raise', 'has_fix_kw', 'has_bug_kw', 'loc_churn_ratio', 'activity_per_exp', 'loc_added_bucket_very_small', 'loc_added_bucket_small', 'loc_added_bucket_medium', 'loc_added_bucket_large', 'loc_added_bucket_very_large', 'author_exp_pre_bucket_junior', 'author_exp_pre_bucket_mid', 'author_exp_pre_bucket_senior', 'line_token_total', 'todo_ratio', 'fixme_ratio', 'try_ratio', 'except_ratio', 'raise_ratio', 'loc_added_x_loc_deleted', 'loc_added_x_hunks_count', 'loc_deleted_x_hunks_count']
# [TRAIN RESULT] 37
# [TRAIN RESULT] embedding_features: ['code_emb_0', 'code_emb_1', 'code_emb_2', 'code_emb_3', 'code_emb_4', 'code_emb_5', 'code_emb_6', 'code_emb_7', 'code_emb_8', 'code_emb_9', 'msg_emb_0', 'msg_emb_1', 'msg_emb_2', 'msg_emb_3', 'msg_emb_4', 'msg_emb_5', 'msg_emb_6', 'msg_emb_7', 'msg_emb_8', 'msg_emb_9', 'msg_emb_10', 'msg_emb_11', 'msg_emb_12', 'msg_emb_13', 'msg_emb_14', 'msg_emb_15', 'msg_emb_16', 'msg_emb_17', 'msg_emb_18', 'msg_emb_19', 'msg_emb_20', 'msg_emb_21', 'msg_emb_22', 'msg_emb_23', 'msg_emb_24', 'msg_emb_25', 'msg_emb_26', 'msg_emb_27', 'msg_emb_28', 'msg_emb_29', 'msg_emb_30', 'msg_emb_31', 'msg_emb_32', 'msg_emb_33', 'msg_emb_34', 'msg_emb_35', 'msg_emb_36', 'msg_emb_37', 'msg_emb_38', 'msg_emb_39', 'msg_emb_40', 'msg_emb_41', 'msg_emb_42', 'msg_emb_43', 'msg_emb_44']
# [TRAIN RESULT] Analysis completed.

# %% [markdown]
# ### 7.2.4 Train / Test Split (Stratified)

# %%
display_func(split_train_test)
# Out:
# <style>
# .jp-CodeCell .highlight,
# .output pre,
# .output code {
#     background-color: #111111 !important;
#     color: #94d4d4 !important;
# }
# </style>
# def split_train_test(
#     df: pd.DataFrame,
#     target: str,
#     random_state: int,
#     test_size: float,
#     logger: NotebookLogger = DEF_NOTEBOOK_LOGGER,
# ):
#     logger.log_check("Splitting df into train & test subsets...")
#     n_rows = len(df)
#     n_features = df.shape[1] - 1  # excluding target
#
#     logger.log_result(f"Total rows before split: {n_rows}")
#     logger.log_result(f"Feature count (X): {n_features}")
#     logger.log_result(f"Target column: '{target}'")
#     logger.log_result(f"Test size: {test_size:.2%}")
#
#     X = df.drop(columns=[target])
#     y = df[target]
#
#     X_train, X_test, y_train, y_test = train_test_split(
#         X,
#         y,
#         test_size=test_size,
#         # stratify=y, not required since the training subset of the original df is balanced
#         random_state=random_state,
#     )
#
#     logger.log_result(f"Train rows: {len(X_train)} | Test rows: {len(X_test)}")
#
#     logger.log_result("Splitting completed.")
#     return X_train, X_test, y_train, y_test

# %%
# X = df.drop(columns=[TARGET])
# y = df[TARGET]

# X_train, X_test, y_train, y_test = train_test_split(
#     X,
#     y,
#     test_size=0.2,
#     # stratify=y, not required since the training subset of the original df is balanced
#     random_state=RANDOM_STATE
# )

# from main_config import TEST_SPLIT

X_train, X_test, y_train, y_test = split_train_test(
    df=df, target=TARGET, random_state=RANDOM_STATE, test_size=TEST_SPLIT, logger=logger
)
# Out:
# [TRAIN CHECK] Splitting df into train & test subsets...
# [TRAIN RESULT] Total rows before split: 139545
# [TRAIN RESULT] Feature count (X): 92
# [TRAIN RESULT] Target column: 'label'
# [TRAIN RESULT] Test size: 20.00%
# [TRAIN RESULT] Train rows: 111636 | Test rows: 27909
# [TRAIN RESULT] Splitting completed.

# %% [markdown]
# ### 7.2.5 Preprocessing Pipeline

# %% [markdown]
# Design choices (aligned with the EDA):
# - No scaling for trees
# - Remove zero-variance features
# - Keep engineered features (selection later)
#
# Why VarianceThreshold is useful: This step removes any numerical features that have zero variance (i.e., all values are identical). Features with zero variance provide no information to the model and can sometimes cause issues or slow down training, so it's good practice to remove them.
#
# #### PCA
# PCA is an unsupervised linear transformation technique used for dimensionality reduction. Its goal is to reduce the number of features while retaining as much of the original variance (information) as possible.
#
# `n_components` is the target number of dimensions. PCA will transform the original 768 embedding features into a new, smaller set of 100 features.
#
# **In Context:** You are combining 768 Code embeddings and 768 Message embeddings, resulting in 1536 embedding features. PCA reduces this set of 1536 features down to a manageable and non-redundant set of 100 features that still capture most of the semantic meaning.

# %% [markdown]
# ### 7.2.5 Baseline Random Forest Model
#
# This combined object, model, is a Pipeline, which ensures that the preprocessing steps are always applied correctly before the Random Forest Classifier is trained or used for prediction.

# %%
# rf = RandomForestClassifier(
#     n_estimators=300,
#     max_depth=20,
#     # min_samples_leaf=2,
#     random_state=RANDOM_STATE,
#     max_features="log2",
#     min_samples_split=2,
#     # class_weight=CLASS_WEIGHT,
#     n_jobs=1              # 🔴 IMPORTANT
# )

# model = Pipeline(steps=[
#     # ("preprocess", preprocessor),
#     ("rf", rf)
# ])

rf_wrapper = RFWrapper(random_state=RANDOM_STATE)
model = rf_wrapper.get_model()
rf_pipeline = RFPipelineWrapper(rf=model)
# Out:
# [DEF LOGGER CHECK] Defining Random Forest...
# [DEF LOGGER RESULT] Model definition done.
# [DEF LOGGER CHECK] Defining RF Pipeline...
# [DEF LOGGER RESULT] Pipeline definition done.

# %% [markdown]
# ### 7.2.6 Hyperparameter Tuning

# %%
rf_tuning_wrapper = RFTuningWrapper(rf=model, X_train=X_train, y_train=y_train)

display_func(rf_tuning_wrapper.run_grid_search)
# Out:
# [DEF LOGGER CHECK] Initializing RFTunning Wrapper object...
# [DEF LOGGER RESULT] Initialization completed.
# <style>
# .jp-CodeCell .highlight,
# .output pre,
# .output code {
#     background-color: #111111 !important;
#     color: #94d4d4 !important;
# }
# </style>
#     def run_grid_search(self):
#         # 5. Run the search
#         self.logger.log_check("Running grid search...")
#
#         start = time.time()
#         self.grid_search.fit(self.X_train, self.y_train)
#         end = time.time()
#
#         best_params = self.grid_search.best_params_
#         best_score = self.grid_search.best_score_
#
#         self.logger.log_result(f"Search complete. Time: {end - start:2f}")
#         self.logger.log_result(f"Best Parameters: {best_params}")
#         self.logger.log_result(f"Best MCC Score: {best_score}")
#
#         return best_params, best_score

# %%
rf_tuning_wrapper = RFTuningWrapper(rf=model, X_train=X_train, y_train=y_train)
best_params, best_score = rf_tuning_wrapper.run_grid_search()
# --- Update Model ---
model.set_params(**best_params)  # make sure pipeline/model uses the tuned parameters
# Out:
# [DEF LOGGER CHECK] Initializing RFTunning Wrapper object...
# [DEF LOGGER RESULT] Initialization completed.
# [DEF LOGGER CHECK] Running grid search...
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 2
#       1 rf_tuning_wrapper = RFTuningWrapper(rf=model, X_train=X_train, y_train=y_train)
# ----> 2 best_params, best_score = rf_tuning_wrapper.run_grid_search()
#       3 # --- Update Model ---
#       4 model.set_params(**best_params)  # make sure pipeline/model uses the tuned parameters
#
# File ~\Code\DPThesis\DP_Thesis\src_code\ml_pipeline\training\tuning.py:56, in RFTuningWrapper.run_grid_search(self)
#      53 self.logger.log_check("Running grid search...")
#      55 start = time.time()
# ---> 56 self.grid_search.fit(self.X_train, self.y_train)
#      57 end = time.time()
#      59 best_params = self.grid_search.best_params_
#
# File c:\Users\fmojt\.virtualenvs\DP_Thesis-sh7Ft33M\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\fmojt\.virtualenvs\DP_Thesis-sh7Ft33M\Lib\site-packages\sklearn\model_selection\_search.py:1053, in BaseSearchCV.fit(self, X, y, **params)
#    1047     results = self._format_results(
#    1048         all_candidate_params, n_splits, all_out, all_more_results
#    1049     )
#    1051     return results
# -> 1053 self._run_search(evaluate_candidates)
#    1055 # multimetric is determined here because in the case of a callable
#    1056 # self.scoring the return type is only known after calling
#    1057 first_test_score = all_out[0]["test_scores"]
#
# File c:\Users\fmojt\.virtualenvs\DP_Thesis-sh7Ft33M\Lib\site-packages\sklearn\model_selection\_search.py:1612, in GridSearchCV._run_search(self, evaluate_candidates)
#    1610 def _run_search(self, evaluate_candidates):
#    1611     """Search all candidates in param_grid"""
# -> 1612     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File c:\Users\fmojt\.virtualenvs\DP_Thesis-sh7Ft33M\Lib\site-packages\sklearn\model_selection\_search.py:999, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     991 if self.verbose > 0:
#     992     print(
#     993         "Fitting {0} folds for each of {1} candidates,"
#     994         " totalling {2} fits".format(
#     995             n_splits, n_candidates, n_candidates * n_splits
#     996         )
#     997     )
# --> 999 out = parallel(
#    1000     delayed(_fit_and_score)(
#    1001         clone(base_estimator),
#    1002         X,
#    1003         y,
#    1004         train=train,
#    1005         test=test,
#    1006         parameters=parameters,
#    1007         split_progress=(split_idx, n_splits),
#    1008         candidate_progress=(cand_idx, n_candidates),
#    1009         **fit_and_score_kwargs,
#    1010     )
#    1011     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#    1012         enumerate(candidate_params),
#    1013         enumerate(cv.split(X, y, **routed_params.splitter.split)),
#    1014     )
#    1015 )
#    1017 if len(out) < 1:
#    1018     raise ValueError(
#    1019         "No fits were performed. "
#    1020         "Was the CV iterator empty? "
#    1021         "Were there no candidates?"
#    1022     )
#
# File c:\Users\fmojt\.virtualenvs\DP_Thesis-sh7Ft33M\Lib\site-packages\sklearn\utils\parallel.py:91, in Parallel.__call__(self, iterable)
#      79 warning_filters = (
#      80     filters_func() if filters_func is not None else warnings.filters
#      81 )
#      83 iterable_with_config_and_warning_filters = (
#      84     (
#      85         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     89     for delayed_func, args, kwargs in iterable
#      90 )
# ---> 91 return super().__call__(iterable_with_config_and_warning_filters)
#
# File c:\Users\fmojt\.virtualenvs\DP_Thesis-sh7Ft33M\Lib\site-packages\joblib\parallel.py:2072, in Parallel.__call__(self, iterable)
#    2066 # The first item from the output is blank, but it makes the interpreter
#    2067 # progress until it enters the Try/Except block of the generator and
#    2068 # reaches the first `yield` statement. This starts the asynchronous
#    2069 # dispatch of the tasks to the workers.
#    2070 next(output)
# -> 2072 return output if self.return_generator else list(output)
#
# File c:\Users\fmojt\.virtualenvs\DP_Thesis-sh7Ft33M\Lib\site-packages\joblib\parallel.py:1682, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1679     yield
#    1681     with self._backend.retrieval_context():
# -> 1682         yield from self._retrieve()
#    1684 except GeneratorExit:
#    1685     # The generator has been garbage collected before being fully
#    1686     # consumed. This aborts the remaining tasks if possible and warn
#    1687     # the user if necessary.
#    1688     self._exception = True
#
# File c:\Users\fmojt\.virtualenvs\DP_Thesis-sh7Ft33M\Lib\site-packages\joblib\parallel.py:1800, in Parallel._retrieve(self)
#    1789 if self.return_ordered:
#    1790     # Case ordered: wait for completion (or error) of the next job
#    1791     # that have been dispatched and not retrieved yet. If no job
#    (...)   1795     # control only have to be done on the amount of time the next
#    1796     # dispatched job is pending.
#    1797     if (nb_jobs == 0) or (
#    1798         self._jobs[0].get_status(timeout=self.timeout) == TASK_PENDING
#    1799     ):
# -> 1800         time.sleep(0.01)
#    1801         continue
#    1803 elif nb_jobs == 0:
#    1804     # Case unordered: jobs are added to the list of jobs to
#    1805     # retrieve `self._jobs` only once completed or in error, which
#    (...)   1811     # timeouts before any other dispatched job has completed and
#    1812     # been added to `self._jobs` to be retrieved.
#
# KeyboardInterrupt:

# %% [markdown]
# ### 7.2.7 Cross-Validation (Primary Evaluation)

# %%
cv_wrapper = CVWrapper(random_state=RANDOM_STATE)
display_func(cv_wrapper.cross_validate)
display_func(cv_wrapper.mean_results)
# Out:
# [DEF LOGGER CHECK] Defining cross-validation...
# [DEF LOGGER RESULT] Validation definition done.
# <style>
# .jp-CodeCell .highlight,
# .output pre,
# .output code {
#     background-color: #111111 !important;
#     color: #94d4d4 !important;
# }
# </style>
#     def cross_validate(self, model, X_train, y_train):
#         self.logger.log_check("Cross validating provided model...")
#         start = time.time()
#
#         # -------------------------------------------------------------------------
#         # 3. Execute the cross-validation
#         # -------------------------------------------------------------------------
#         self.cv_results = cross_validate(
#             model,  # Your machine learning pipeline
#             X_train,  # Training features
#             y_train,  # Training labels
#             cv=self.cv,  # The KFold splitter
#             scoring=self.scoring,
#             # n_jobs=6,  # Use CPU cores
#             n_jobs=self.n_jobs,
#             verbose=3,
#         )
#
#         end = time.time()
#
#         self.logger.log_result(f"Validation completed. Time: {end-start:2f}")
#
#         return self.cv_results
# <style>
# .jp-CodeCell .highlight,
# .output pre,
# .output code {
#     background-color: #111111 !important;
#     color: #94d4d4 !important;
# }
# </style>
#     def mean_results(self):
#         # -------------------------------------------------------------------------
#         # 4. View and aggregate the results
#         # -------------------------------------------------------------------------
#         # The mean of the results gives the model's average performance.
#         average_metrics = pd.DataFrame(self.cv_results).mean()
#
#         self.logger.log_result("\n--- Average Cross-Validation Metrics (KFold) ---")
#         self.logger.log_result(average_metrics)

# %%
# # -------------------------------------------------------------------------
# # 1. Define the KFold splitter (non-stratified)
# # -------------------------------------------------------------------------
# # NOTE: This does NOT guarantee equal class proportions in each fold.
# from sklearn.model_selection import KFold


# cv = KFold(n_splits=10, shuffle=True, random_state=RANDOM_STATE)

# # -------------------------------------------------------------------------
# # 2. Define the scoring metrics
# # -------------------------------------------------------------------------
# scoring = {
#     "roc_auc": "roc_auc",
#     "f1": "f1",
#     "precision": "precision",
#     "recall": "recall"
# }

# # -------------------------------------------------------------------------
# # 3. Execute the cross-validation
# # -------------------------------------------------------------------------
# cv_results = cross_validate(
#     model,      # Your machine learning pipeline
#     X_train,    # Training features
#     y_train,    # Training labels
#     cv=cv,      # The KFold splitter
#     scoring=scoring,
#     n_jobs=6,    # Use CPU cores
#     verbose=3
# )

# # -------------------------------------------------------------------------
# # 4. View and aggregate the results
# # -------------------------------------------------------------------------
# # The mean of the results gives the model's average performance.
# average_metrics = pd.DataFrame(cv_results).mean()

# print("\n--- Average Cross-Validation Metrics (KFold) ---")
# print(average_metrics)

cv_wrapper = CVWrapper(random_state=RANDOM_STATE)
cv_results = cv_wrapper.cross_validate(
    model=model, X_train=X_train, y_train=y_train
)

cv_wrapper.mean_results()
# Out:
# [DEF LOGGER CHECK] Defining cross-validation...
# [DEF LOGGER RESULT] Validation definition done.
# [DEF LOGGER CHECK] Cross validating provided model...
# [Parallel(n_jobs=10)]: Using backend LokyBackend with 10 concurrent workers.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 45
#      41 from src_code.ml_pipeline.validations import CVWrapper
#      44 cv_wrapper = CVWrapper(random_state=RANDOM_STATE)
# ---> 45 cv_results = cv_wrapper.cross_validate(
#      46     model=model, X_train=X_train, y_train=y_train
#      47 )
#      49 cv_wrapper.mean_results()
#
# File ~\Code\DPThesis\DP_Thesis\src_code\ml_pipeline\validations.py:48, in CVWrapper.cross_validate(self, model, X_train, y_train)
#      43 start = time.time()
#      45 # -------------------------------------------------------------------------
#      46 # 3. Execute the cross-validation
#      47 # -------------------------------------------------------------------------
# ---> 48 self.cv_results = cross_validate(
#      49     model,  # Your machine learning pipeline
#      50     X_train,  # Training features
#      51     y_train,  # Training labels
#      52     cv=self.cv,  # The KFold splitter
#      53     scoring=self.scoring,
#      54     # n_jobs=6,  # Use CPU cores
#      55     n_jobs=self.n_jobs,
#      56     verbose=3,
#      57 )
#      59 end = time.time()
#      61 self.logger.log_result(f"Validation completed. Time: {end-start:2f}")
#
# File c:\Users\fmojt\.virtualenvs\DP_Thesis-sh7Ft33M\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File c:\Users\fmojt\.virtualenvs\DP_Thesis-sh7Ft33M\Lib\site-packages\sklearn\model_selection\_validation.py:373, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, params, pre_dispatch, return_train_score, return_estimator, return_indices, error_score)
#     370 # We clone the estimator to make sure that all the folds are
#     371 # independent, and that it is pickle-able.
#     372 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 373 results = parallel(
#     374     delayed(_fit_and_score)(
#     375         clone(estimator),
#     376         X,
#     377         y,
#     378         scorer=scorers,
#     379         train=train,
#     380         test=test,
#     381         verbose=verbose,
#     382         parameters=None,
#     383         fit_params=routed_params.estimator.fit,
#     384         score_params=routed_params.scorer.score,
#     385         return_train_score=return_train_score,
#     386         return_times=True,
#     387         return_estimator=return_estimator,
#     388         error_score=error_score,
#     389     )
#     390     for train, test in indices
#     391 )
#     393 _warn_or_raise_about_fit_failures(results, error_score)
#     395 # For callable scoring, the return type is only know after calling. If the
#     396 # return type is a dictionary, the error scores can now be inserted with
#     397 # the correct key.
#
# File c:\Users\fmojt\.virtualenvs\DP_Thesis-sh7Ft33M\Lib\site-packages\sklearn\utils\parallel.py:91, in Parallel.__call__(self, iterable)
#      79 warning_filters = (
#      80     filters_func() if filters_func is not None else warnings.filters
#      81 )
#      83 iterable_with_config_and_warning_filters = (
#      84     (
#      85         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     89     for delayed_func, args, kwargs in iterable
#      90 )
# ---> 91 return super().__call__(iterable_with_config_and_warning_filters)
#
# File c:\Users\fmojt\.virtualenvs\DP_Thesis-sh7Ft33M\Lib\site-packages\joblib\parallel.py:2072, in Parallel.__call__(self, iterable)
#    2066 # The first item from the output is blank, but it makes the interpreter
#    2067 # progress until it enters the Try/Except block of the generator and
#    2068 # reaches the first `yield` statement. This starts the asynchronous
#    2069 # dispatch of the tasks to the workers.
#    2070 next(output)
# -> 2072 return output if self.return_generator else list(output)
#
# File c:\Users\fmojt\.virtualenvs\DP_Thesis-sh7Ft33M\Lib\site-packages\joblib\parallel.py:1682, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1679     yield
#    1681     with self._backend.retrieval_context():
# -> 1682         yield from self._retrieve()
#    1684 except GeneratorExit:
#    1685     # The generator has been garbage collected before being fully
#    1686     # consumed. This aborts the remaining tasks if possible and warn
#    1687     # the user if necessary.
#    1688     self._exception = True
#
# File c:\Users\fmojt\.virtualenvs\DP_Thesis-sh7Ft33M\Lib\site-packages\joblib\parallel.py:1800, in Parallel._retrieve(self)
#    1789 if self.return_ordered:
#    1790     # Case ordered: wait for completion (or error) of the next job
#    1791     # that have been dispatched and not retrieved yet. If no job
#    (...)   1795     # control only have to be done on the amount of time the next
#    1796     # dispatched job is pending.
#    1797     if (nb_jobs == 0) or (
#    1798         self._jobs[0].get_status(timeout=self.timeout) == TASK_PENDING
#    1799     ):
# -> 1800         time.sleep(0.01)
#    1801         continue
#    1803 elif nb_jobs == 0:
#    1804     # Case unordered: jobs are added to the list of jobs to
#    1805     # retrieve `self._jobs` only once completed or in error, which
#    (...)   1811     # timeouts before any other dispatched job has completed and
#    1812     # been added to `self._jobs` to be retrieved.
#
# KeyboardInterrupt:

# %% [markdown]
# ### 7.2.8 Model fit

# %%
display_func(fit_model)
# Out:
# <style>
# .jp-CodeCell .highlight,
# .output pre,
# .output code {
#     background-color: #111111 !important;
#     color: #94d4d4 !important;
# }
# </style>
# def fit_model(
#     model: BaseEstimator,
#     X_train,
#     y_train,
#     logger: NotebookLogger = DEF_NOTEBOOK_LOGGER,
# ):
#     # This step trains the single, final model pipeline that is saved
#     # in the 'model' variable and used for prediction and PFI.
#     logger.log_check("Starting model fit...")
#
#     start = time.time()
#     model.fit(X_train, y_train)
#     end = time.time()
#
#     logger.log_result(f"Model fit completed. Time: {end - start:2f}")
#     return model

# %%
# This step trains the single, final model pipeline that is saved
# in the 'model' variable and used for prediction and PFI.
# model.fit(X_train, y_train)
# from src_code.ml_pipeline.training.train import fit_model


model = fit_model(model=model, X_train=X_train, y_train=y_train)
# Out:
# [DEF LOGGER CHECK] Starting model fit...
# [DEF LOGGER RESULT] Model fit completed. Time: 124.375742

# %% [markdown]
# ### 7.2.9 Single inference check

# %%
display_func(check_single_infer)
# Out:
# <style>
# .jp-CodeCell .highlight,
# .output pre,
# .output code {
#     background-color: #111111 !important;
#     color: #94d4d4 !important;
# }
# </style>
# def check_single_infer(
#     model: BaseEstimator,
#     X_test,
#     logger: NotebookLogger = DEF_NOTEBOOK_LOGGER,
# ):
#     logger.log_check("Checking single model inference...")
#     start_time = time.time()
#
#     # This call runs the entire pipeline: Preprocessing (PCA) + Random Forest Prediction
#     # The output is not needed, just the execution time.
#     _ = model.predict(X_test)
#
#     end_time = time.time()
#     single_inference_duration = end_time - start_time
#     logger.log_result("Inference done.")
#
#     logger.log_result(
#         f"Time for a single inference run on X_test ({len(X_test)} rows): {single_inference_duration:.2f} seconds"
#     )
#
#     # logger.log_result("")

# %%
# import time

# start_time = time.time()

# # This call runs the entire pipeline: Preprocessing (PCA) + Random Forest Prediction
# # The output is not needed, just the execution time.
# _ = model.predict(X_test)

# end_time = time.time()
# single_inference_duration = end_time - start_time

# print(f"Time for a single inference run on X_test ({len(X_test)} rows): {single_inference_duration:.2f} seconds")

check_single_infer(model=model, X_test=X_test, logger=logger)
# Out:
# [TRAIN CHECK] Checking single model inference...
# [TRAIN RESULT] Inference done.
# [TRAIN RESULT] Time for a single inference run on X_test (27909 rows): 1.60 seconds

# %% [markdown]
# ### 7.2.10 Feature Importance (Permutation-Based)
#
# Critical due to correlated engineered features
#
# You are calculating and displaying the **Permutation Feature Importance (PFI)** for your entire machine learning pipeline (model) using the held-out test set. This is a crucial step in model interpretation, especially for complex models like Random Forests.
#
# The permutation_importance function calculates the drop in a model's score when a single feature is randomly shuffled (permuted).
#
# How it Works:
#
# 1. The function first calculates the model's baseline score (e.g., ROC AUC) on the unshuffled X_test and y_test.
#
# 2. For each feature (e.g., lines_added), it randomly shuffles the values in that column across the entire X_test set.
#
# 3. It then recalculates the model's score using this corrupted data.
#
# 4. The Permutation Importance is the difference between the baseline score and the score with the shuffled feature. A large drop in score indicates the feature was highly important.

# %%
X_test_small = X_test.sample(n=5000, random_state=RANDOM_STATE)
y_test_small = y_test.loc[X_test_small.index]

pfi_wrapper = PFIWrapper(
    model=model,
    X_test=X_test_small,
    y_test=y_test_small,
    random_state=RANDOM_STATE,
    logger=logger,
)

display_func(pfi_wrapper.run_PFI)
display_func(pfi_wrapper.calc_importances)
# Out:
# [TRAIN CHECK] Initializing PFI wrapper..
# [TRAIN CHECK] Initialization done.
# <style>
# .jp-CodeCell .highlight,
# .output pre,
# .output code {
#     background-color: #111111 !important;
#     color: #94d4d4 !important;
# }
# </style>
#     def run_PFI(self):
#         self.logger.log_check("Starting PFI...")
#         self.perm = permutation_importance(
#             self.model,
#             self.X_test,
#             self.y_test,
#             n_repeats=self.n_repeats,
#             random_state=self.random_state,
#             n_jobs=self.n_jobs,  # <--- Re-enabled parallel processing
#         )
#
#         self.logger.log_result("PFI completed.")
# <style>
# .jp-CodeCell .highlight,
# .output pre,
# .output code {
#     background-color: #111111 !important;
#     color: #94d4d4 !important;
# }
# </style>
#     def calc_importances(self):
#         self.logger.log_check("Calculating PFI importances...")
#         self.importances = pd.Series(
#             self.perm.importances_mean,  # Retrieves the average importance score
#             # (the average drop in model performance)
#             # calculated across the n_repeats=2 runs
#             # for each feature.
#             # index=model.named_steps["preprocess"].get_feature_names_out()\
#             index=self.X_test.columns,
#             # This is a crucial step for pipelines. After the ColumnTransformer
#             # ("preprocess") has run (including PCA and any other steps), the feature
#             #  names are transformed (e.g., code_emb_0 becomes embed__pca__0). This
#             # method retrieves the correct, final feature names that the model actually used.
#         ).sort_values(ascending=False)
#         self.logger.log_result("Calculation complete.")

# %%
TOP_K = 20


# pfi_wrapper = PFIWrapper(
#     model=model,
#     X_test=X_test_small,
#     y_test=y_test_small,
#     random_state=RANDOM_STATE,
#     logger=logger,
# )

pfi_wrapper.run_PFI()
pfi_wrapper.calc_importances()
importances = pfi_wrapper.get_importances(top_k=TOP_K)


# # The total number of tasks is N_features * n_repeats
# # n_features = len(model.named_steps["preprocess"].get_feature_names_out())
# n_features = X_test_small.shape[1]
# total_tasks = n_features * 2

# # with parallel_backend('loky', n_jobs=-1): # Use all cores
#     # with tqdm.tqdm(total=total_tasks, desc="PFI Permutations") as progress_bar:
#         # Wrap the function call in a helper that updates the progress bar
#         # This is a bit advanced but forces joblib to use the tqdm callback

# # NOTE: In modern scikit-learn/joblib, simply setting the backend
# # is often enough to show the progress. If not, this is the safest way:
# perm = permutation_importance(
#     model,
#     X_test_small,
#     y_test_small,
#     n_repeats=2,
#     random_state=RANDOM_STATE,
#     n_jobs=6, # <--- Re-enabled parallel processing
# )

# importances = pd.Series(
#     perm.importances_mean, # Retrieves the average importance score
#                             # (the average drop in model performance)
#                             # calculated across the n_repeats=2 runs
#                             # for each feature.
#     # index=model.named_steps["preprocess"].get_feature_names_out()\
#     index=X_test_small.columns

#     # This is a crucial step for pipelines. After the ColumnTransformer
#     # ("preprocess") has run (including PCA and any other steps), the feature
#     #  names are transformed (e.g., code_emb_0 becomes embed__pca__0). This
#     # method retrieves the correct, final feature names that the model actually used.
# ).sort_values(ascending=False)

# importances.head(20)
# Out:
# [TRAIN CHECK] Starting PFI...
# [TRAIN RESULT] PFI completed.
# [TRAIN CHECK] Calculating PFI importances...
# [TRAIN RESULT] Calculation complete.
# [TRAIN RESULT] Top 20 PFI features:
# [TRAIN RESULT]  1. max_func_change: 0.007300
# [TRAIN RESULT]  2. msg_len: 0.005900
# [TRAIN RESULT]  3. msg_emb_0: 0.005800
# [TRAIN RESULT]  4. loc_deleted_x_hunks_count: 0.005600
# [TRAIN RESULT]  5. msg_emb_3: 0.004300
# [TRAIN RESULT]  6. ast_delta: 0.003700
# [TRAIN RESULT]  7. loc_added_x_hunks_count: 0.003500
# [TRAIN RESULT]  8. code_emb_2: 0.003300
# [TRAIN RESULT]  9. hunks_count: 0.003300
# [TRAIN RESULT] 10. loc_added_x_loc_deleted: 0.003100
# [TRAIN RESULT] 11. loc_deleted: 0.003000
# [TRAIN RESULT] 12. loc_churn_ratio: 0.002800
# [TRAIN RESULT] 13. code_emb_4: 0.002800
# [TRAIN RESULT] 14. code_emb_0: 0.002700
# [TRAIN RESULT] 15. code_emb_7: 0.002500
# [TRAIN RESULT] 16. msg_emb_22: 0.002400
# [TRAIN RESULT] 17. code_emb_5: 0.002300
# [TRAIN RESULT] 18. msg_emb_24: 0.002200
# [TRAIN RESULT] 19. msg_emb_14: 0.002200
# [TRAIN RESULT] 20. code_emb_1: 0.002200

# %% [markdown]
# PFI is generally preferred because:
#
# 1. **Model Agnostic**: It works for any model (Random Forest, Neural Network, etc.).
#
# 2. **Includes Preprocessing**: It measures the importance of features after they have gone through the entire pipeline (including PCA), giving you the importance of the final, processed features, which is essential when dealing with complex pipelines.

# %%
# for index, (key, value) in enumerate(importances.items()):
#     print(f"{index}. {key}: {value}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 for index, (key, value) in enumerate(importances.items()):
#       2     print(f"{index}. {key}: {value}")
#
# AttributeError: 'zip' object has no attribute 'items'

# %% [markdown]
# #### 7.2.10.1 Feature Subset Refinement (Optional Iteration)
# (Re-run steps 8–11 using reduced feature set)

# %%
display_func(pfi_wrapper.refine_features)
# Out:
# <style>
# .jp-CodeCell .highlight,
# .output pre,
# .output code {
#     background-color: #111111 !important;
#     color: #94d4d4 !important;
# }
# </style>
#     def refine_features(self, X_train, X_test, threshold: float = 0.0001):
#         self.logger.log_check("Refining features based on best PFI importances...")
#         # threshold = 0.0001 # Or use 0.0 to be more inclusive
#         top_features = self.importances[self.importances > threshold].index.tolist()
#
#         # Filter your training and testing sets
#         X_train_filtered = X_train[top_features]
#         X_test_filtered = X_test[top_features]
#         # df_test = pd.read_feather(ENGINEERING_MAPPINGS['test']['output'])
#         # top_filter = top_features.copy()
#         # top_filter.append('label')
#         # print(top_filter)
#         # df_test = df_test[top_filter]
#         # df_test.to_feather("lala.feather")
#
#         self.logger.log_result(
#             f"Reduced feature count from {len(self.importances)} to {len(top_features)}"
#         )
#         return X_train_filtered, X_test_filtered

# %%
threshold = 0.0001 # Or use 0.0 to be more inclusive
# top_features = importances[importances > threshold].index.tolist()

# # Filter your training and testing sets
# X_train_filtered = X_train[top_features]
# X_test_filtered = X_test[top_features]
# # df_test = pd.read_feather(ENGINEERING_MAPPINGS['test']['output'])
# # top_filter = top_features.copy()
# # top_filter.append('label')
# # print(top_filter)
# # df_test = df_test[top_filter]
# # df_test.to_feather("lala.feather")


# print(f"Reduced feature count from {len(importances)} to {len(top_features)}")

X_train, X_test = pfi_wrapper.refine_features(X_train=X_train, X_test=X_test, threshold=threshold)
# Out:
# [TRAIN CHECK] Refining features based on best PFI importances...
# [TRAIN RESULT] Reduced feature count from 92 to 77

# %% [markdown]
# #### 7.2.10.2 Retraining

# %%
# This step trains the single, final model pipeline that is saved
# in the 'model' variable and used for prediction and PFI.
# model.fit(X_train_filtered, y_train)
# model.fit(X_train, y_train)
model = fit_model(model=model, X_train=X_train, y_train=y_train, logger=logger)
# Out:
# RandomForestClassifier(max_depth=20, max_features='log2', n_estimators=300,
#                        n_jobs=1, random_state=42)

# %% [markdown]
# ### 7.2.11 RCEV (alternative to TFI, just demo)

# %%
# from sklearn.feature_selection import RFECV
# from sklearn.model_selection import StratifiedKFold

# # 1. Use the RF model we already defined
# # Note: RFECV uses 'feature_importances_' (built-in) which is faster than Permutation
# rf = RandomForestClassifier(
#     n_estimators=100, 
#     class_weight='balanced', 
#     random_state=42,
#     n_jobs=-1
# )

# # 2. Set up the selector
# # we use StratifiedKFold to keep the bug/no-bug ratio consistent
# min_features_to_select = 5 
# step = 1 # remove 1 feature at a time

# selector = RFECV(
#     estimator=rf,
#     step=step,
#     cv=StratifiedKFold(5),
#     scoring=mcc_scorer, # Using the MCC scorer we made earlier!
#     min_features_to_select=min_features_to_select,
#     n_jobs=-1,
#     verbose=1
# )

# # 3. Fit to the training data
# selector = selector.fit(X_train, y_train)

# # 4. Results
# print(f"Optimal number of features: {selector.n_features_}")
# selected_features = X_train.columns[selector.support_].tolist()
# print(f"Selected Features: {selected_features}")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[93], line 29
#      18 selector = RFECV(
#      19     estimator=rf,
#      20     step=step,
#    (...)     25     verbose=1
#      26 )
#      28 # 3. Fit to the training data
# ---> 29 selector = selector.fit(X_train, y_train)
#      31 # 4. Results
#      32 print(f"Optimal number of features: {selector.n_features_}")
#
# File c:\Users\fmojt\.virtualenvs\DP_Thesis-sh7Ft33M\Lib\site-packages\sklearn\base.py:1336, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1329     estimator._validate_params()
#    1331 with config_context(
#    1332     skip_parameter_validation=(
#    1333         prefer_skip_nested_validation or global_skip_validation
#    1334     )
#    1335 ):
# -> 1336     return fit_method(estimator, *args, **kwargs)
#
# File c:\Users\fmojt\.virtualenvs\DP_Thesis-sh7Ft33M\Lib\site-packages\sklearn\feature_selection\_rfe.py:891, in RFECV.fit(self, X, y, **params)
#     888     parallel = Parallel(n_jobs=self.n_jobs)
#     889     func = delayed(_rfe_single_fit)
# --> 891 step_results = parallel(
#     892     func(clone(rfe), self.estimator, X, y, train, test, scorer, routed_params)
#     893     for train, test in cv.split(X, y, **routed_params.splitter.split)
#     894 )
#     895 scores, supports, rankings, step_n_features = zip(*step_results)
#     897 step_n_features_rev = np.array(step_n_features[0])[::-1]
#
# File c:\Users\fmojt\.virtualenvs\DP_Thesis-sh7Ft33M\Lib\site-packages\sklearn\utils\parallel.py:91, in Parallel.__call__(self, iterable)
#      79 warning_filters = (
#      80     filters_func() if filters_func is not None else warnings.filters
#      81 )
#      83 iterable_with_config_and_warning_filters = (
#      84     (
#      85         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     89     for delayed_func, args, kwargs in iterable
#      90 )
# ---> 91 return super().__call__(iterable_with_config_and_warning_filters)
#
# File c:\Users\fmojt\.virtualenvs\DP_Thesis-sh7Ft33M\Lib\site-packages\joblib\parallel.py:2072, in Parallel.__call__(self, iterable)
#    2066 # The first item from the output is blank, but it makes the interpreter
#    2067 # progress until it enters the Try/Except block of the generator and
#    2068 # reaches the first `yield` statement. This starts the asynchronous
#    2069 # dispatch of the tasks to the workers.
#    2070 next(output)
# -> 2072 return output if self.return_generator else list(output)
#
# File c:\Users\fmojt\.virtualenvs\DP_Thesis-sh7Ft33M\Lib\site-packages\joblib\parallel.py:1682, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1679     yield
#    1681     with self._backend.retrieval_context():
# -> 1682         yield from self._retrieve()
#    1684 except GeneratorExit:
#    1685     # The generator has been garbage collected before being fully
#    1686     # consumed. This aborts the remaining tasks if possible and warn
#    1687     # the user if necessary.
#    1688     self._exception = True
#
# File c:\Users\fmojt\.virtualenvs\DP_Thesis-sh7Ft33M\Lib\site-packages\joblib\parallel.py:1800, in Parallel._retrieve(self)
#    1789 if self.return_ordered:
#    1790     # Case ordered: wait for completion (or error) of the next job
#    1791     # that have been dispatched and not retrieved yet. If no job
#    (...)   1795     # control only have to be done on the amount of time the next
#    1796     # dispatched job is pending.
#    1797     if (nb_jobs == 0) or (
#    1798         self._jobs[0].get_status(timeout=self.timeout) == TASK_PENDING
#    1799     ):
# -> 1800         time.sleep(0.01)
#    1801         continue
#    1803 elif nb_jobs == 0:
#    1804     # Case unordered: jobs are added to the list of jobs to
#    1805     # retrieve `self._jobs` only once completed or in error, which
#    (...)   1811     # timeouts before any other dispatched job has completed and
#    1812     # been added to `self._jobs` to be retrieved.
#
# KeyboardInterrupt:

# %% [markdown]
# ## 7.3 Saving the Model
#
# *joblib.dump()* is used to save the model object to a file. It is generally preferred over standard Python pickle for large objects containing NumPy arrays (like your Random Forest and PCA objects).

# %%
display_func(save_model)
# Out:
# <style>
# .jp-CodeCell .highlight,
# .output pre,
# .output code {
#     background-color: #111111 !important;
#     color: #94d4d4 !important;
# }
# </style>
# def save_model(model: BaseEstimator, path: Path, logger: NotebookLogger = DEF_NOTEBOOK_LOGGER):
#     # Ensure the directory exists
#     logger.log_check("Saving the trained model...")
#     os.makedirs("models", exist_ok=True)
#     # MODEL_SAVE_PATH = MODEL_DIR / "random_forest_pipeline.joblib"
#     # Save the entire fitted pipeline
#     joblib.dump(model, path)
#     logger.log_result("Saving done.")

# %%
# Define the filename (e.g., in a 'models' directory)
# MODEL_SAVE_PATH = "models/random_forest_pipeline.joblib"
MODEL_SAVE_PATH = MODEL_DIR / "random_forest_pipeline.joblib"
# log_check("Saving the model ")

# # Ensure the directory exists
# os.makedirs("models", exist_ok=True)
# MODEL_SAVE_PATH = MODEL_DIR / "random_forest_pipeline.joblib"
# # Save the entire fitted pipeline
# joblib.dump(model, MODEL_DIR / MODEL_SAVE_PATH)

# log_result(f"✅ Model successfully saved to: {MODEL_SAVE_PATH}", print_to_console=True)
# save_df(df=df, df_file_path=MODEL_SAVE_PATH, logger=logger)
save_model(model=model, path=MODEL_SAVE_PATH, logger=logger)
# Out:
# [TRAIN CHECK] Saving the trained model...
# [TRAIN RESULT] Saving done.

# %%
# df_test_path = ENGINEERING_MAPPINGS['test']['output']
# # top_features.append('label')
# df_test = pd.read_feather(df_test_path)
# df_test = df_test[top_features]

# df_test.columns
# df_test.to_feather("test.feather")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[157], line 7
#       4 df_test = df_test[top_features]
#       6 df_test.columns
# ----> 7 df_test.to_feather("test.feather")
#
# File c:\Users\fmojt\.virtualenvs\DP_Thesis-sh7Ft33M\Lib\site-packages\pandas\core\frame.py:2949, in DataFrame.to_feather(self, path, **kwargs)
#    2921 """
#    2922 Write a DataFrame to the binary Feather format.
#    2923
#    (...)   2945 >>> df.to_feather("file.feather")  # doctest: +SKIP
#    2946 """
#    2947 from pandas.io.feather_format import to_feather
# -> 2949 to_feather(self, path, **kwargs)
#
# File c:\Users\fmojt\.virtualenvs\DP_Thesis-sh7Ft33M\Lib\site-packages\pandas\io\feather_format.py:65, in to_feather(df, path, storage_options, **kwargs)
#      60     raise ValueError("feather only support IO with DataFrames")
#      62 with get_handle(
#      63     path, "wb", storage_options=storage_options, is_text=False
#      64 ) as handles:
# ---> 65     feather.write_feather(df, handles.handle, **kwargs)
#
# File c:\Users\fmojt\.virtualenvs\DP_Thesis-sh7Ft33M\Lib\site-packages\pyarrow\feather.py:156, in write_feather(df, dest, compression, compression_level, chunksize, version)
#     153 else:
#     154     raise ValueError("Version value should either be 1 or 2")
# --> 156 table = Table.from_pandas(df, preserve_index=preserve_index)
#     158 if version == 1:
#     159     # Version 1 does not chunking
#     160     for i, name in enumerate(table.schema.names):
#
# File c:\Users\fmojt\.virtualenvs\DP_Thesis-sh7Ft33M\Lib\site-packages\pyarrow\table.pxi:4795, in pyarrow.lib.Table.from_pandas()
#
# File c:\Users\fmojt\.virtualenvs\DP_Thesis-sh7Ft33M\Lib\site-packages\pyarrow\pandas_compat.py:597, in dataframe_to_arrays(df, schema, preserve_index, nthreads, columns, safe)
#     588 def dataframe_to_arrays(df, schema, preserve_index, nthreads=1, columns=None,
#     589                         safe=True):
#     590     (all_names,
#     591      column_names,
#     592      column_field_names,
#     593      index_column_names,
#     594      index_descriptors,
#     595      index_columns,
#     596      columns_to_convert,
# --> 597      convert_fields) = _get_columns_to_convert(df, schema, preserve_index,
#     598                                                columns)
#     600     # NOTE(wesm): If nthreads=None, then we use a heuristic to decide whether
#     601     # using a thread pool is worth it. Currently the heuristic is whether the
#     602     # nrows > 100 * ncols and ncols > 1.
#     603     if nthreads is None:
#
# File c:\Users\fmojt\.virtualenvs\DP_Thesis-sh7Ft33M\Lib\site-packages\pyarrow\pandas_compat.py:377, in _get_columns_to_convert(df, schema, preserve_index, columns)
#     374 columns = _resolve_columns_of_interest(df, schema, columns)
#     376 if not df.columns.is_unique:
# --> 377     raise ValueError(
#     378         f'Duplicate column names found: {list(df.columns)}'
#     379     )
#     381 if schema is not None:
#     382     return _get_columns_to_convert_given_schema(df, schema, preserve_index)
#
# ValueError: Duplicate column names found: ['has_bug_kw', 'loc_added_x_hunks_count', 'line_token_total', 'ast_delta', 'msg_emb_20', 'code_emb_3', 'loc_deleted', 'msg_emb_8', 'loc_deleted_x_hunks_count', 'label', 'msg_emb_0', 'max_func_change', 'msg_len', 'msg_emb_3', 'hunks_count', 'has_fix_kw', 'code_emb_8', 'code_emb_2', 'code_emb_5', 'loc_added_bucket_cat', 'author_exp_pre', 'label']

# %%
# from sklearn.ensemble import RandomForestClassifier
# from sklearn.metrics import make_scorer, matthews_corrcoef
# from sklearn.model_selection import GridSearchCV

# # 1. Define the model
# rf = RandomForestClassifier(random_state=42, class_weight='balanced')

# # 2. Define the parameter grid
# param_grid = {
#     'n_estimators': [100, 200, 300],
#     'max_depth': [10, 20],
#     'min_samples_split': [2, 5, 10],
#     'max_features': ['sqrt', 'log2']
# }

# # 3. Create a custom scorer for MCC
# mcc_scorer = make_scorer(matthews_corrcoef)

# # 4. Set up Grid Search
# grid_search = GridSearchCV(
#     estimator=rf, 
#     param_grid=param_grid, 
#     scoring=mcc_scorer, 
#     cv=5,            # 5-fold cross-validation
#     n_jobs=1,       # Use all CPU cores
#     verbose=3
# )

# # 5. Run the search
# grid_search.fit(X_train, y_train)

# print(f"Best Parameters: {grid_search.best_params_}")
# print(f"Best MCC Score: {grid_search.best_score_}")
# from src_code.ml_pipeline.training.tuning import RFTuningWrapper


# rf_tuning_wrapper = RFTuningWrapper(rf=model, X_train=X_train, y_train=y_train)
# best_params, best_score = rf_tuning_wrapper.run_grid_search()
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=100;, score=0.614 total time=  36.1s
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=100;, score=0.611 total time=  37.9s
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=100;, score=0.613 total time=  36.1s
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=100;, score=0.610 total time=  35.5s
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=100;, score=0.614 total time=  36.4s
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=200;, score=0.616 total time= 1.1min
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=200;, score=0.611 total time= 1.1min
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=200;, score=0.613 total time= 1.1min
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=200;, score=0.612 total time= 1.2min
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=200;, score=0.612 total time= 1.3min
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=300;, score=0.617 total time= 2.0min
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=300;, score=0.611 total time= 1.8min
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=300;, score=0.617 total time= 1.8min
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=300;, score=0.614 total time= 1.7min
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_split=2, n_estimators=300;, score=0.613 total time= 1.6min
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100;, score=0.614 total time=  33.8s
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100;, score=0.619 total time=  37.5s
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100;, score=0.613 total time=  35.4s
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100;, score=0.611 total time=  34.8s
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=100;, score=0.611 total time=  38.3s
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200;, score=0.613 total time= 1.3min
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200;, score=0.615 total time= 1.2min
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200;, score=0.611 total time= 1.2min
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200;, score=0.613 total time= 1.2min
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=200;, score=0.608 total time= 1.0min
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=300;, score=0.613 total time= 1.4min
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=300;, score=0.613 total time= 1.7min
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=300;, score=0.613 total time= 1.8min
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=300;, score=0.611 total time= 1.8min
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_split=5, n_estimators=300;, score=0.609 total time= 1.8min
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_split=10, n_estimators=100;, score=0.613 total time=  35.9s
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_split=10, n_estimators=100;, score=0.611 total time=  36.1s
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_split=10, n_estimators=100;, score=0.607 total time=  36.7s
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_split=10, n_estimators=100;, score=0.614 total time=  31.7s
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_split=10, n_estimators=100;, score=0.605 total time=  36.5s
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_split=10, n_estimators=200;, score=0.613 total time= 1.1min
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_split=10, n_estimators=200;, score=0.611 total time= 1.2min
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_split=10, n_estimators=200;, score=0.611 total time= 1.2min
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_split=10, n_estimators=200;, score=0.612 total time= 1.2min
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_split=10, n_estimators=200;, score=0.608 total time= 1.3min
# [CV 1/5] END max_depth=10, max_features=sqrt, min_samples_split=10, n_estimators=300;, score=0.613 total time= 1.8min
# [CV 2/5] END max_depth=10, max_features=sqrt, min_samples_split=10, n_estimators=300;, score=0.612 total time= 1.8min
# [CV 3/5] END max_depth=10, max_features=sqrt, min_samples_split=10, n_estimators=300;, score=0.609 total time= 1.8min
# [CV 4/5] END max_depth=10, max_features=sqrt, min_samples_split=10, n_estimators=300;, score=0.611 total time= 1.8min
# [CV 5/5] END max_depth=10, max_features=sqrt, min_samples_split=10, n_estimators=300;, score=0.607 total time= 1.8min
# [CV 1/5] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=100;, score=0.604 total time=  25.1s
# [CV 2/5] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=100;, score=0.602 total time=  25.1s
# [CV 3/5] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=100;, score=0.602 total time=  24.4s
# [CV 4/5] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=100;, score=0.602 total time=  24.1s
# [CV 5/5] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=100;, score=0.603 total time=  24.1s
# [CV 1/5] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=200;, score=0.603 total time=  49.5s
# [CV 2/5] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=200;, score=0.604 total time=  49.9s
# [CV 3/5] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=200;, score=0.605 total time=  50.5s
# [CV 4/5] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=200;, score=0.600 total time=  50.6s
# [CV 5/5] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=200;, score=0.604 total time=  50.9s
# [CV 1/5] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=300;, score=0.605 total time= 1.2min
# [CV 2/5] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=300;, score=0.605 total time= 1.3min
# [CV 3/5] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=300;, score=0.606 total time= 1.3min
# [CV 4/5] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=300;, score=0.601 total time= 1.3min
# [CV 5/5] END max_depth=10, max_features=log2, min_samples_split=2, n_estimators=300;, score=0.604 total time= 1.3min
# [CV 1/5] END max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.604 total time=  24.9s
# [CV 2/5] END max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.603 total time=  26.1s
# [CV 3/5] END max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.602 total time=  24.5s
# [CV 4/5] END max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.605 total time=  25.0s
# [CV 5/5] END max_depth=10, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.602 total time=  25.7s
# [CV 1/5] END max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.603 total time=  49.8s
# [CV 2/5] END max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.603 total time=  53.9s
# [CV 3/5] END max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.601 total time=  50.2s
# [CV 4/5] END max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.609 total time=  51.4s
# [CV 5/5] END max_depth=10, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.600 total time=  51.0s
# [CV 1/5] END max_depth=10, max_features=log2, min_samples_split=5, n_estimators=300;, score=0.605 total time= 1.3min
# [CV 2/5] END max_depth=10, max_features=log2, min_samples_split=5, n_estimators=300;, score=0.602 total time= 1.3min
# [CV 3/5] END max_depth=10, max_features=log2, min_samples_split=5, n_estimators=300;, score=0.603 total time= 1.3min
# [CV 4/5] END max_depth=10, max_features=log2, min_samples_split=5, n_estimators=300;, score=0.606 total time= 5.1min
# [CV 5/5] END max_depth=10, max_features=log2, min_samples_split=5, n_estimators=300;, score=0.600 total time= 1.3min
# [CV 1/5] END max_depth=10, max_features=log2, min_samples_split=10, n_estimators=100;, score=0.599 total time=  24.6s
# [CV 2/5] END max_depth=10, max_features=log2, min_samples_split=10, n_estimators=100;, score=0.601 total time=  24.7s
# [CV 3/5] END max_depth=10, max_features=log2, min_samples_split=10, n_estimators=100;, score=0.597 total time=  28.0s
# [CV 4/5] END max_depth=10, max_features=log2, min_samples_split=10, n_estimators=100;, score=0.603 total time=  28.8s
# [CV 5/5] END max_depth=10, max_features=log2, min_samples_split=10, n_estimators=100;, score=0.600 total time=  30.1s
# [CV 1/5] END max_depth=10, max_features=log2, min_samples_split=10, n_estimators=200;, score=0.599 total time=  52.3s
# [CV 2/5] END max_depth=10, max_features=log2, min_samples_split=10, n_estimators=200;, score=0.601 total time=  53.6s
# [CV 3/5] END max_depth=10, max_features=log2, min_samples_split=10, n_estimators=200;, score=0.599 total time=  50.8s
# [CV 4/5] END max_depth=10, max_features=log2, min_samples_split=10, n_estimators=200;, score=0.602 total time=  50.9s
# [CV 5/5] END max_depth=10, max_features=log2, min_samples_split=10, n_estimators=200;, score=0.597 total time=  50.9s
# [CV 1/5] END max_depth=10, max_features=log2, min_samples_split=10, n_estimators=300;, score=0.603 total time= 1.3min
# [CV 2/5] END max_depth=10, max_features=log2, min_samples_split=10, n_estimators=300;, score=0.602 total time= 1.3min
# [CV 3/5] END max_depth=10, max_features=log2, min_samples_split=10, n_estimators=300;, score=0.601 total time= 1.2min
# [CV 4/5] END max_depth=10, max_features=log2, min_samples_split=10, n_estimators=300;, score=0.602 total time= 1.2min
# [CV 5/5] END max_depth=10, max_features=log2, min_samples_split=10, n_estimators=300;, score=0.599 total time= 1.2min
# [CV 1/5] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=100;, score=0.827 total time=  56.0s
# [CV 2/5] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=100;, score=0.827 total time=  56.7s
# [CV 3/5] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=100;, score=0.827 total time=  57.5s
# [CV 4/5] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=100;, score=0.831 total time=  59.7s
# [CV 5/5] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=100;, score=0.827 total time=  57.2s
# [CV 1/5] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=200;, score=0.826 total time= 1.7min
# [CV 2/5] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=200;, score=0.831 total time= 2.0min
# [CV 3/5] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=200;, score=0.828 total time= 2.0min
# [CV 4/5] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=200;, score=0.831 total time= 1.6min
# [CV 5/5] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=200;, score=0.829 total time= 1.9min
# [CV 1/5] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=300;, score=0.828 total time= 3.0min
# [CV 2/5] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=300;, score=0.833 total time= 3.1min
# [CV 3/5] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=300;, score=0.829 total time= 3.1min
# [CV 4/5] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=300;, score=0.833 total time= 3.1min
# [CV 5/5] END max_depth=20, max_features=sqrt, min_samples_split=2, n_estimators=300;, score=0.829 total time= 3.0min
# [CV 1/5] END max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=100;, score=0.822 total time=  58.1s
# [CV 2/5] END max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=100;, score=0.828 total time=  58.4s
# [CV 3/5] END max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=100;, score=0.827 total time=  52.8s
# [CV 4/5] END max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=100;, score=0.827 total time=  55.6s
# [CV 5/5] END max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=100;, score=0.824 total time=  59.7s
# [CV 1/5] END max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=200;, score=0.823 total time= 1.8min
# [CV 2/5] END max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=200;, score=0.827 total time= 1.9min
# [CV 3/5] END max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=200;, score=0.826 total time= 1.4min
# [CV 4/5] END max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=200;, score=0.830 total time= 1.5min
# [CV 5/5] END max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=200;, score=0.826 total time= 1.5min
# [CV 1/5] END max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=300;, score=0.821 total time= 2.1min
# [CV 2/5] END max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=300;, score=0.828 total time= 2.6min
# [CV 3/5] END max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=300;, score=0.827 total time= 2.9min
# [CV 4/5] END max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=300;, score=0.829 total time= 3.5min
# [CV 5/5] END max_depth=20, max_features=sqrt, min_samples_split=5, n_estimators=300;, score=0.825 total time= 3.5min
# [CV 1/5] END max_depth=20, max_features=sqrt, min_samples_split=10, n_estimators=100;, score=0.815 total time= 1.1min
# [CV 2/5] END max_depth=20, max_features=sqrt, min_samples_split=10, n_estimators=100;, score=0.822 total time= 1.2min
# [CV 3/5] END max_depth=20, max_features=sqrt, min_samples_split=10, n_estimators=100;, score=0.820 total time= 1.2min
# [CV 4/5] END max_depth=20, max_features=sqrt, min_samples_split=10, n_estimators=100;, score=0.821 total time= 1.1min
# [CV 5/5] END max_depth=20, max_features=sqrt, min_samples_split=10, n_estimators=100;, score=0.820 total time= 1.1min
# [CV 1/5] END max_depth=20, max_features=sqrt, min_samples_split=10, n_estimators=200;, score=0.815 total time= 2.1min
# [CV 2/5] END max_depth=20, max_features=sqrt, min_samples_split=10, n_estimators=200;, score=0.824 total time= 1.7min
# [CV 3/5] END max_depth=20, max_features=sqrt, min_samples_split=10, n_estimators=200;, score=0.822 total time= 2.3min
# [CV 4/5] END max_depth=20, max_features=sqrt, min_samples_split=10, n_estimators=200;, score=0.825 total time= 2.3min
# [CV 5/5] END max_depth=20, max_features=sqrt, min_samples_split=10, n_estimators=200;, score=0.821 total time= 2.3min
# [CV 1/5] END max_depth=20, max_features=sqrt, min_samples_split=10, n_estimators=300;, score=0.815 total time= 3.3min
# [CV 2/5] END max_depth=20, max_features=sqrt, min_samples_split=10, n_estimators=300;, score=0.822 total time= 3.2min
# [CV 3/5] END max_depth=20, max_features=sqrt, min_samples_split=10, n_estimators=300;, score=0.822 total time= 3.4min
# [CV 4/5] END max_depth=20, max_features=sqrt, min_samples_split=10, n_estimators=300;, score=0.824 total time= 3.4min
# [CV 5/5] END max_depth=20, max_features=sqrt, min_samples_split=10, n_estimators=300;, score=0.821 total time= 3.1min
# [CV 1/5] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=100;, score=0.827 total time=  48.2s
# [CV 2/5] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=100;, score=0.832 total time=  48.0s
# [CV 3/5] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=100;, score=0.829 total time=  49.0s
# [CV 4/5] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=100;, score=0.832 total time=  47.6s
# [CV 5/5] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=100;, score=0.829 total time=  46.3s
# [CV 1/5] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=200;, score=0.826 total time= 1.6min
# [CV 2/5] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=200;, score=0.834 total time= 1.6min
# [CV 3/5] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=200;, score=0.831 total time= 1.6min
# [CV 4/5] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=200;, score=0.834 total time= 1.5min
# [CV 5/5] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=200;, score=0.829 total time= 1.5min
# [CV 1/5] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=300;, score=0.828 total time= 2.3min
# [CV 2/5] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=300;, score=0.834 total time= 2.4min
# [CV 3/5] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=300;, score=0.831 total time= 2.6min
# [CV 4/5] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=300;, score=0.834 total time= 2.4min
# [CV 5/5] END max_depth=20, max_features=log2, min_samples_split=2, n_estimators=300;, score=0.830 total time= 2.3min
# [CV 1/5] END max_depth=20, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.823 total time=  46.8s
# [CV 2/5] END max_depth=20, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.830 total time=  46.5s
# [CV 3/5] END max_depth=20, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.826 total time=  47.0s
# [CV 4/5] END max_depth=20, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.829 total time=  46.3s
# [CV 5/5] END max_depth=20, max_features=log2, min_samples_split=5, n_estimators=100;, score=0.821 total time=  47.1s
# [CV 1/5] END max_depth=20, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.823 total time= 1.6min
# [CV 2/5] END max_depth=20, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.829 total time= 1.6min
# [CV 3/5] END max_depth=20, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.827 total time= 1.5min
# [CV 4/5] END max_depth=20, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.829 total time= 1.1min
# [CV 5/5] END max_depth=20, max_features=log2, min_samples_split=5, n_estimators=200;, score=0.824 total time= 1.5min
# [CV 1/5] END max_depth=20, max_features=log2, min_samples_split=5, n_estimators=300;, score=0.825 total time= 2.3min
# [CV 2/5] END max_depth=20, max_features=log2, min_samples_split=5, n_estimators=300;, score=0.833 total time= 2.3min
# [CV 3/5] END max_depth=20, max_features=log2, min_samples_split=5, n_estimators=300;, score=0.829 total time= 2.2min
# [CV 4/5] END max_depth=20, max_features=log2, min_samples_split=5, n_estimators=300;, score=0.832 total time= 2.2min
# [CV 5/5] END max_depth=20, max_features=log2, min_samples_split=5, n_estimators=300;, score=0.824 total time= 2.4min
# [CV 1/5] END max_depth=20, max_features=log2, min_samples_split=10, n_estimators=100;, score=0.817 total time=  46.8s
# [CV 2/5] END max_depth=20, max_features=log2, min_samples_split=10, n_estimators=100;, score=0.821 total time=  46.6s
# [CV 3/5] END max_depth=20, max_features=log2, min_samples_split=10, n_estimators=100;, score=0.818 total time=  46.4s
# [CV 4/5] END max_depth=20, max_features=log2, min_samples_split=10, n_estimators=100;, score=0.821 total time=  46.3s
# [CV 5/5] END max_depth=20, max_features=log2, min_samples_split=10, n_estimators=100;, score=0.815 total time=  46.2s
# [CV 1/5] END max_depth=20, max_features=log2, min_samples_split=10, n_estimators=200;, score=0.814 total time= 1.5min
# [CV 2/5] END max_depth=20, max_features=log2, min_samples_split=10, n_estimators=200;, score=0.824 total time= 1.5min
# [CV 3/5] END max_depth=20, max_features=log2, min_samples_split=10, n_estimators=200;, score=0.821 total time= 1.5min
# [CV 4/5] END max_depth=20, max_features=log2, min_samples_split=10, n_estimators=200;, score=0.824 total time= 1.5min
# [CV 5/5] END max_depth=20, max_features=log2, min_samples_split=10, n_estimators=200;, score=0.817 total time= 1.5min
# [CV 1/5] END max_depth=20, max_features=log2, min_samples_split=10, n_estimators=300;, score=0.816 total time= 1.9min
# [CV 2/5] END max_depth=20, max_features=log2, min_samples_split=10, n_estimators=300;, score=0.824 total time= 2.1min
# [CV 3/5] END max_depth=20, max_features=log2, min_samples_split=10, n_estimators=300;, score=0.820 total time= 2.4min
# [CV 4/5] END max_depth=20, max_features=log2, min_samples_split=10, n_estimators=300;, score=0.825 total time= 2.2min
# [CV 5/5] END max_depth=20, max_features=log2, min_samples_split=10, n_estimators=300;, score=0.817 total time= 2.1min
# Best Parameters: {'max_depth': 20, 'max_features': 'log2', 'min_samples_split': 2, 'n_estimators': 300}
# Best MCC Score: 0.8315164202824172
