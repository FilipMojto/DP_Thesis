# %% [markdown]
# # 03 - Checking Data Consistency

# %% [markdown]
# ## Setting Up Project Directory

# %%
from jupyter_init import setup

setup()

from src_code.config import *

# %% [markdown]
# ## Loading Dataset

# %%
import pandas as pd
import numpy as np

TRANSFORMED_DF = EXTRACTED_DATA_DIR / "train_labeled_features_partial_copy.feather"

# ---- LOAD ----
df = pd.read_feather(TRANSFORMED_DF)
print(f"Loaded dataframe with {len(df)} rows and {len(df.columns)} columns\n")

df.dtypes
# Out:
# Loaded dataframe with 23479 rows and 31 columns
# datetime                      datetime64[us, pytz.FixedOffset(-120)]
# commit                                                        object
# repo                                                          object
# filepath                                                      object
# content                                                       object
# methods                                                       object
# lines                                                         object
# author_email                                                  object
# canonical_datetime                               datetime64[ns, UTC]
# author_exp_pre                                                 int64
# author_recent_activity_pre                                     int64
# label                                                          int64
# loc_added                                                      int64
# loc_deleted                                                    int64
# files_changed                                                  int64
# hunks_count                                                    int64
# msg_len                                                        int64
# has_fix_kw                                                     int64
# has_bug_kw                                                     int64
# ast_delta                                                      int64
# complexity_delta                                               int64
# max_func_change                                                int64
# time_since_last_change                                         int64
# todo                                                           int64
# fixme                                                          int64
# try                                                            int64
# except                                                         int64
# raise                                                          int64
# code_embed                                                    object
# msg_embed                                                     object
# recent_churn                                                   int64
# dtype: object

# %% [markdown]
# ## Converting NumpyArray -> List

# %%
#Convert the NumPy arrays back to Python lists
for col in ['code_embed', 'msg_embed', 'methods', 'lines']:
    # Use .apply(list) or .apply(lambda x: x.tolist()) for robustness
    df[col] = df[col].apply(list)

# print(df['content'].head(5))

# %% [markdown]
# ## Missing Value Audit

# %%
print("## 1. Missing Values per Column")
nulls = df.isnull().sum().sort_values(ascending=False)
print(nulls.to_markdown())
# Out:
# ## 1. Missing Values per Column
# |                            |   0 |
# |:---------------------------|----:|
# | datetime                   |   0 |
# | commit                     |   0 |
# | repo                       |   0 |
# | filepath                   |   0 |
# | content                    |   0 |
# | methods                    |   0 |
# | lines                      |   0 |
# | author_email               |   0 |
# | canonical_datetime         |   0 |
# | author_exp_pre             |   0 |
# | author_recent_activity_pre |   0 |
# | label                      |   0 |
# | loc_added                  |   0 |
# | loc_deleted                |   0 |
# | files_changed              |   0 |
# | hunks_count                |   0 |
# | msg_len                    |   0 |
# | has_fix_kw                 |   0 |
# | has_bug_kw                 |   0 |
# | ast_delta                  |   0 |
# | complexity_delta           |   0 |
# | max_func_change            |   0 |
# | time_since_last_change     |   0 |
# | todo                       |   0 |
# | fixme                      |   0 |
# | try                        |   0 |
# | except                     |   0 |
# | raise                      |   0 |
# | code_embed                 |   0 |
# | msg_embed                  |   0 |
# | recent_churn               |   0 |

# %% [markdown]
# ## Primary Key Integrity

# %%
print("## 2. Primary Key Uniqueness Check")
key_cols = ["repo", "commit", "filepath"]

dupes = df.duplicated(subset=key_cols).sum()
print(f"Duplicate key rows: {dupes}")
# Out:
# ## 2. Primary Key Uniqueness Check
# Duplicate key rows: 0

# %% [markdown]
# ## Label Distribution

# %%
print("## 3. Label Distribution")
print(df['label'].value_counts(normalize=True).to_markdown())
# Out:
# ## 3. Label Distribution
# |   label |   proportion |
# |--------:|-------------:|
# |       1 |     0.517859 |
# |       0 |     0.482141 |

# %% [markdown]
# ## Repository Distribution (Imbalance Check)

# %%
print("## 4. Repository Distribution")
repo_dist = df['repo'].value_counts(normalize=True)
print(repo_dist.to_markdown())
# Out:
# ## 4. Repository Distribution
# | repo    |   proportion |
# |:--------|-------------:|
# | pandas  |     0.644913 |
# | airflow |     0.355087 |

# %% [markdown]
# ## Value Range Scan for Numeric Columns
#
# Automatically detects:
#
# - negatives where not allowed
# - max values
# - suspicious spikes

# %%
print("## 5. Numeric Column Range Scan")
num_cols = df.select_dtypes(include=[np.number]).columns

ranges = pd.DataFrame({
    "min": df[num_cols].min(),
    "median": df[num_cols].median(),
    "mean": df[num_cols].mean(),
    "max": df[num_cols].max()
})

print(ranges.to_markdown())
# Out:
# ## 5. Numeric Column Range Scan
# |                            |     min |   median |          mean |              max |
# |:---------------------------|--------:|---------:|--------------:|-----------------:|
# | author_exp_pre             |       0 |     84   |   412.41      |   3557           |
# | author_recent_activity_pre |       0 |     14   |    33.0938    |    238           |
# | label                      |       0 |      1   |     0.517859  |      1           |
# | loc_added                  |       0 |     36   |    85.0857    |  11824           |
# | loc_deleted                |       0 |     63   |   124.98      |  12067           |
# | files_changed              |       0 |      7   |    16.1322    |    214           |
# | hunks_count                |       0 |     32   |    76.5818    |   1104           |
# | msg_len                    |       7 |     65   |   137.041     |   3814           |
# | has_fix_kw                 |       0 |      0   |     0.2004    |      1           |
# | has_bug_kw                 |       0 |      0   |     0.129054  |      1           |
# | ast_delta                  |       0 |      2   |    90.0466    |   6535           |
# | complexity_delta           |       0 |      0   |     3.51373   |    287           |
# | max_func_change            |       0 |     82   |   104.041     |    501           |
# | time_since_last_change     | -396818 |   2991   | 20751.8       |      2.04664e+07 |
# | todo                       |       0 |      0   |     0.132474  |     26           |
# | fixme                      |       0 |      0   |     0.0137272 |     17           |
# | try                        |       0 |      0   |     1.15806   |    660           |
# | except                     |       0 |      0   |     1.58992   |    128           |
# | raise                      |       0 |      0   |     1.57606   |    213           |
# | recent_churn               |       0 |   1882.5 |  6193.08      | 110348           |

# %% [markdown]
# ## Check Columns Expected to Be Non-Negative

# %%
non_negative_cols = [
    "loc_added", "loc_deleted",
    "files_changed", "hunks_count",
    "msg_len", "ast_delta",
    "complexity_delta", "max_func_change",
    "author_exp_pre", "author_recent_activity_pre",
    "todo", "fixme", "try", "except", "raise",
    "recent_churn"
]

print("## 6. Negative Value Check")
for col in non_negative_cols:
    bad = (df[col] < 0).sum()
    print(f"{col}: {bad} negative values")
# Out:
# ## 6. Negative Value Check
# loc_added: 0 negative values
# loc_deleted: 0 negative values
# files_changed: 0 negative values
# hunks_count: 0 negative values
# msg_len: 0 negative values
# ast_delta: 0 negative values
# complexity_delta: 0 negative values
# max_func_change: 0 negative values
# author_exp_pre: 0 negative values
# author_recent_activity_pre: 0 negative values
# todo: 0 negative values
# fixme: 0 negative values
# try: 0 negative values
# except: 0 negative values
# raise: 0 negative values
# recent_churn: 0 negative values

# %% [markdown]
# ## Suspicious Feature Check: time_since_last_change

# %%
print("## 7. time_since_last_change Outliers")
tslc = df["time_since_last_change"]

print(f"Negative values: {(tslc < 0).sum()}")
print(f"99.9% quantile: {tslc.quantile(0.999)}")
print(f"Min: {tslc.min()}")
print(f"Max: {tslc.max()}")
# Out:
# ## 7. time_since_last_change Outliers
# Negative values: 3
# 99.9% quantile: 981249.0
# Min: -396818
# Max: 20466389

# %% [markdown]
# ### Understanding the Feature
#
# *time_since_last_change = c.committed_date - last_time*
#
# Where:
# - c.committed_date = current commit timestamp (UNIX seconds)
# - last_time = timestamp of first parent commit
#
# So the feature = time difference between consecutive commits.
#
# This represents how much time passed between commits in a repo.
#
# ### Why Negative Values?
#
# Meaning:
#
# - Some commits appear to be ~4.6 days negative (-396,818 sec)
# - Some commits appear to be ~77 days ahead (6.6M sec)
#
# This is expected when real Git data is used.
#
# Git timestamps can go backwards because:
#
# #### (1) Rebased or rewritten history
#
# During rebases, old commits appear “later” than newer ones.
#
# *WHY?*
#
# When you merge/rebase, Git does not reorder commits chronologically.
# Instead, it preserves the logical order of development.
#
# #### (2) Merge parents
#
# You use only the first parent:
#
# if c.parents:
#     last_time = c.parents[0].committed_date
#
#
# But merges may introduce non-linear time ordering.
#
# #### (3) Clock drift
#
# Different authors → different local machine clocks.
#
# #### (4) Shallow clones or incomplete history
#
# If the repo is shallow-fetched, parent commits may have weird timestamps.
#
# None of this indicates your extraction is wrong.

# %% [markdown]
# ## Binary Flag Integity

# %%
print("## 8. Binary Columns Integrity")
bin_cols = ["has_fix_kw", "has_bug_kw"]

for col in bin_cols:
    bad = df[~df[col].isin([0,1])]
    print(f"{col}: {len(bad)} invalid values")
# Out:
# ## 8. Binary Columns Integrity
# has_fix_kw: 0 invalid values
# has_bug_kw: 0 invalid values

# %% [markdown]
# ## Embedding Consistency Check
#
# Ensure:
#
# - no None
# - all lists
# - identical dimensionality

# %%
# # Convert the NumPy arrays back to Python lists
# for col in ['code_embed', 'msg_embed']:
#     # Use .apply(list) or .apply(lambda x: x.tolist()) for robustness
#     df[col] = df[col].apply(list)

print(type(df.loc[0, 'code_embed']))
print(type(df.loc[0, 'msg_embed']))

print("## 9. Embedding Structural Checks")

# None count
print("code_embed None count:", df['code_embed'].isna().sum())
print("msg_embed None count:", df['msg_embed'].isna().sum())

# Check if all are lists
print("\nNon-list code_embed rows:", (~df['code_embed'].apply(lambda x: isinstance(x, list))).sum())
print("Non-list msg_embed rows:", (~df['msg_embed'].apply(lambda x: isinstance(x, list))).sum())

# Check dimensionality
dims = df['code_embed'].apply(lambda x: len(x) if isinstance(x, list) else None)
print("\nEmbedding dimensionality distribution:")
print(dims.value_counts().head())
# Out:
# <class 'list'>
# <class 'list'>
# ## 9. Embedding Structural Checks
# code_embed None count: 0
# msg_embed None count: 0
#
# Non-list code_embed rows: 0
# Non-list msg_embed rows: 0
#
# Embedding dimensionality distribution:
# code_embed
# 768    22510
# Name: count, dtype: int64

# %% [markdown]
# ## Datetime Consistency
#
# Check for:
#
# - NaT values
# - ordering sanity (commit should not be older than file's previous record)

# %%
print("## 10. Datetime Columns Audit")

date_cols = ["datetime", "canonical_datetime"]

for col in date_cols:
    print(f"{col}: NaT count = {df[col].isna().sum()}")
    print(f"{col}: min = {df[col].min()}, max = {df[col].max()}")
# Out:
# ## 10. Datetime Columns Audit
# datetime: NaT count = 0
# datetime: min = 2009-11-21 20:57:45-02:00, max = 2022-01-03 09:36:56-02:00
# canonical_datetime: NaT count = 0
# canonical_datetime: min = 2009-11-21 22:57:45+00:00, max = 2022-01-03 21:36:56+00:00

# %% [markdown]
# ## Correlation Hot Spots
# To detect redundant or suspiciously identical columns.

# %%
print("## 11. Correlations (Numeric Only)")
corr = df[num_cols].corr()
# display(corr.style.background_gradient(cmap='coolwarm'))
matrix = corr.style.background_gradient(cmap='coolwarm')
matrix

# print("## 11. Correlations (Numeric Only)")
# corr = df[num_cols].corr()
# print(corr.to_markdown())  # nicely formatted markdown table
# Out:
# ## 11. Correlations (Numeric Only)
# <style type="text/css">
# #T_b5d1c_row0_col0, #T_b5d1c_row1_col1, #T_b5d1c_row2_col2, #T_b5d1c_row3_col3, #T_b5d1c_row4_col4, #T_b5d1c_row5_col5, #T_b5d1c_row6_col6, #T_b5d1c_row7_col7, #T_b5d1c_row8_col8, #T_b5d1c_row9_col9, #T_b5d1c_row10_col10, #T_b5d1c_row11_col11, #T_b5d1c_row12_col12, #T_b5d1c_row13_col13, #T_b5d1c_row14_col14, #T_b5d1c_row15_col15, #T_b5d1c_row16_col16, #T_b5d1c_row17_col17, #T_b5d1c_row18_col18, #T_b5d1c_row19_col19 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b5d1c_row0_col1 {
#   background-color: #f49a7b;
#   color: #000000;
# }
# #T_b5d1c_row0_col2, #T_b5d1c_row1_col11, #T_b5d1c_row8_col12, #T_b5d1c_row19_col2 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_b5d1c_row0_col3, #T_b5d1c_row0_col10, #T_b5d1c_row0_col18, #T_b5d1c_row7_col18, #T_b5d1c_row8_col2, #T_b5d1c_row17_col13, #T_b5d1c_row18_col13 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_b5d1c_row0_col4, #T_b5d1c_row0_col8, #T_b5d1c_row0_col16, #T_b5d1c_row0_col17, #T_b5d1c_row1_col7, #T_b5d1c_row1_col8, #T_b5d1c_row1_col13, #T_b5d1c_row2_col13, #T_b5d1c_row5_col9, #T_b5d1c_row5_col15, #T_b5d1c_row6_col9, #T_b5d1c_row6_col15, #T_b5d1c_row7_col0, #T_b5d1c_row7_col1, #T_b5d1c_row8_col10, #T_b5d1c_row8_col11, #T_b5d1c_row9_col3, #T_b5d1c_row9_col5, #T_b5d1c_row9_col6, #T_b5d1c_row9_col10, #T_b5d1c_row9_col12, #T_b5d1c_row9_col14, #T_b5d1c_row9_col16, #T_b5d1c_row9_col17, #T_b5d1c_row9_col18, #T_b5d1c_row9_col19, #T_b5d1c_row13_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_b5d1c_row0_col5, #T_b5d1c_row0_col11, #T_b5d1c_row6_col0, #T_b5d1c_row7_col11, #T_b5d1c_row13_col19, #T_b5d1c_row14_col17, #T_b5d1c_row15_col2, #T_b5d1c_row16_col10, #T_b5d1c_row18_col14 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_b5d1c_row0_col6, #T_b5d1c_row13_col12, #T_b5d1c_row16_col11 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_b5d1c_row0_col7 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_b5d1c_row0_col9, #T_b5d1c_row1_col2, #T_b5d1c_row5_col7, #T_b5d1c_row7_col5, #T_b5d1c_row10_col7, #T_b5d1c_row12_col8, #T_b5d1c_row14_col5 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_b5d1c_row0_col12, #T_b5d1c_row5_col8, #T_b5d1c_row6_col8, #T_b5d1c_row8_col17, #T_b5d1c_row13_col1, #T_b5d1c_row18_col16 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_b5d1c_row0_col13, #T_b5d1c_row8_col0, #T_b5d1c_row8_col14, #T_b5d1c_row13_col15 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_b5d1c_row0_col14, #T_b5d1c_row4_col11, #T_b5d1c_row10_col2, #T_b5d1c_row12_col19, #T_b5d1c_row15_col0 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_b5d1c_row0_col15, #T_b5d1c_row7_col17, #T_b5d1c_row13_col3, #T_b5d1c_row17_col2, #T_b5d1c_row18_col15, #T_b5d1c_row19_col9 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_b5d1c_row0_col19, #T_b5d1c_row14_col0 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_b5d1c_row1_col0 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_b5d1c_row1_col3, #T_b5d1c_row2_col9, #T_b5d1c_row4_col1, #T_b5d1c_row10_col9, #T_b5d1c_row11_col14, #T_b5d1c_row14_col10 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_b5d1c_row1_col4, #T_b5d1c_row2_col14, #T_b5d1c_row7_col13, #T_b5d1c_row19_col8 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_b5d1c_row1_col5, #T_b5d1c_row5_col1, #T_b5d1c_row10_col4, #T_b5d1c_row10_col18, #T_b5d1c_row11_col4, #T_b5d1c_row11_col5, #T_b5d1c_row11_col18, #T_b5d1c_row12_col10, #T_b5d1c_row12_col11, #T_b5d1c_row16_col6, #T_b5d1c_row16_col17 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_b5d1c_row1_col6, #T_b5d1c_row2_col1, #T_b5d1c_row6_col11 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_b5d1c_row1_col9, #T_b5d1c_row8_col3, #T_b5d1c_row9_col1, #T_b5d1c_row11_col8, #T_b5d1c_row14_col2, #T_b5d1c_row15_col19, #T_b5d1c_row16_col12 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_b5d1c_row1_col10, #T_b5d1c_row10_col8, #T_b5d1c_row19_col7 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_b5d1c_row1_col12, #T_b5d1c_row14_col6, #T_b5d1c_row15_col1 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_b5d1c_row1_col14, #T_b5d1c_row14_col19, #T_b5d1c_row15_col4, #T_b5d1c_row15_col12, #T_b5d1c_row15_col18, #T_b5d1c_row16_col0, #T_b5d1c_row18_col9 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_b5d1c_row1_col15, #T_b5d1c_row4_col15, #T_b5d1c_row6_col13, #T_b5d1c_row9_col11, #T_b5d1c_row12_col13, #T_b5d1c_row12_col16, #T_b5d1c_row13_col10, #T_b5d1c_row13_col16 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_b5d1c_row1_col16, #T_b5d1c_row8_col19, #T_b5d1c_row9_col2, #T_b5d1c_row16_col15 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_b5d1c_row1_col17, #T_b5d1c_row3_col13, #T_b5d1c_row6_col14, #T_b5d1c_row7_col16, #T_b5d1c_row7_col19, #T_b5d1c_row10_col13, #T_b5d1c_row11_col13, #T_b5d1c_row12_col15, #T_b5d1c_row13_col11, #T_b5d1c_row13_col18, #T_b5d1c_row15_col16, #T_b5d1c_row17_col15 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_b5d1c_row1_col18, #T_b5d1c_row3_col9, #T_b5d1c_row12_col9, #T_b5d1c_row12_col14 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_b5d1c_row1_col19 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_b5d1c_row2_col0, #T_b5d1c_row4_col12, #T_b5d1c_row6_col18, #T_b5d1c_row10_col1 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_b5d1c_row2_col3, #T_b5d1c_row2_col10, #T_b5d1c_row4_col10, #T_b5d1c_row17_col19 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_b5d1c_row2_col4, #T_b5d1c_row2_col11, #T_b5d1c_row11_col2, #T_b5d1c_row15_col10, #T_b5d1c_row17_col8 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_b5d1c_row2_col5, #T_b5d1c_row18_col10 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_b5d1c_row2_col6, #T_b5d1c_row9_col8 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_b5d1c_row2_col7, #T_b5d1c_row6_col1, #T_b5d1c_row18_col11 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_b5d1c_row2_col8, #T_b5d1c_row8_col5, #T_b5d1c_row8_col6, #T_b5d1c_row14_col4, #T_b5d1c_row14_col8, #T_b5d1c_row16_col18, #T_b5d1c_row17_col1 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_b5d1c_row2_col12 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_b5d1c_row2_col15, #T_b5d1c_row3_col15, #T_b5d1c_row7_col14, #T_b5d1c_row8_col1, #T_b5d1c_row8_col16, #T_b5d1c_row13_col14, #T_b5d1c_row16_col14, #T_b5d1c_row17_col14, #T_b5d1c_row19_col13, #T_b5d1c_row19_col15 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_b5d1c_row2_col16, #T_b5d1c_row5_col13, #T_b5d1c_row5_col14, #T_b5d1c_row14_col16 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_b5d1c_row2_col17, #T_b5d1c_row13_col4 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_b5d1c_row2_col18, #T_b5d1c_row4_col16, #T_b5d1c_row5_col10, #T_b5d1c_row6_col16, #T_b5d1c_row11_col9, #T_b5d1c_row13_col5, #T_b5d1c_row13_col6, #T_b5d1c_row16_col8, #T_b5d1c_row16_col9, #T_b5d1c_row17_col10, #T_b5d1c_row18_col0, #T_b5d1c_row18_col2 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_b5d1c_row2_col19, #T_b5d1c_row3_col2, #T_b5d1c_row5_col11, #T_b5d1c_row6_col7, #T_b5d1c_row7_col2, #T_b5d1c_row11_col15, #T_b5d1c_row14_col7, #T_b5d1c_row18_col8 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_b5d1c_row3_col0, #T_b5d1c_row17_col0 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_b5d1c_row3_col1, #T_b5d1c_row17_col12, #T_b5d1c_row18_col19, #T_b5d1c_row19_col11 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_b5d1c_row3_col4, #T_b5d1c_row4_col3 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_b5d1c_row3_col5 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_b5d1c_row3_col6 {
#   background-color: #f1cdba;
#   color: #000000;
# }
# #T_b5d1c_row3_col7, #T_b5d1c_row10_col19, #T_b5d1c_row15_col11 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_b5d1c_row3_col8, #T_b5d1c_row7_col3, #T_b5d1c_row12_col7, #T_b5d1c_row14_col12, #T_b5d1c_row16_col1, #T_b5d1c_row16_col19 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_b5d1c_row3_col10 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_b5d1c_row3_col11 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T

# %%
print("## 12. Columns With Only One Unique Value")

for col in df.columns:
    # Convert arrays to tuples for uniqueness check
    if df[col].apply(lambda x: isinstance(x, (np.ndarray, list))).any():
        # Convert each element to a tuple (or a string representation)
        # print(col)
        unique_values = df[col].apply(lambda x: tuple(x) if isinstance(x, (np.ndarray, list)) else x)
    else:
        unique_values = df[col]

    if unique_values.nunique(dropna=True) == 1:
        print(f"⚠️ {col} has only one unique value")
# Out:
# ## 12. Columns With Only One Unique Value

# %% [markdown]
# ## Check Text Columns for Weirdness
#
# Empty strings? Too short? Too long?

# %%
print("## 13. Text Field Checks")

if 'content' in df.columns:
    print("Empty content rows:", (df['content'].str.len() == 0).sum())
    print(df['content'].str.len().describe())

# Check 'methods' if it is a list column
if 'methods' in df.columns:
    # Use len() on the Python lists
    print("\nEmpty methods rows:", (df['methods'].apply(len) == 0).sum())
    print(df['methods'].apply(len).describe())
# Out:
# ## 13. Text Field Checks
# Empty content rows: 54
# count     22510.000000
# mean       1786.281253
# std        3229.427225
# min           0.000000
# 25%         455.250000
# 50%         858.000000
# 75%        1870.000000
# max      109324.000000
# Name: content, dtype: float64
#
# Empty methods rows: 4863
# count    22510.000000
# mean         2.472768
# std          4.766058
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max        148.000000
# Name: methods, dtype: float64

# %% [markdown]
# ## Check For Impossible Values

# %%
print("## 14. Logical Consistency Checks")

# msg_len should match commit message length
if "msg_len" in df.columns:
    print("msg_len outliers (msg_len <= 0):", (df['msg_len'] <= 0).sum())
# Out:
# ## 14. Logical Consistency Checks
# msg_len outliers (msg_len <= 0): 0

# %% [markdown]
# ## Filepath Sanity
# Check for Windows vs POSIX weirdness.

# %%
# Normalize all filepaths to use forward slashes
df['filepath'] = df['filepath'].str.replace('\\', '/', regex=False)

# Check again for paths without a slash
bad_paths = df[~df['filepath'].str.contains('/')]
print("Filepaths without / (unexpected after normalization):", len(bad_paths))
print(df.loc[~df['filepath'].str.contains('/'), 'filepath'].head(20))
# Out:
# Filepaths without / (unexpected after normalization): 400
# 11        setup.py
# 80        setup.py
# 81     setupegg.py
# 122       setup.py
# 123       setup.py
# 138       setup.py
# 144       setup.py
# 168       setup.py
# 278       setup.py
# 461       setup.py
# 462       setup.py
# 479       setup.py
# 497       setup.py
# 513       setup.py
# 514       setup.py
# 523       setup.py
# 524       setup.py
# 531       setup.py
# 562       setup.py
# 570       setup.py
# Name: filepath, dtype: object

# %% [markdown]
# ## Check Recent Churn for Extreme Outliers

# %%
print("## 16. recent_churn Outlier Scan")
print(df['recent_churn'].describe())
print("99.9% quantile:", df['recent_churn'].quantile(0.999))
# Out:
# ## 16. recent_churn Outlier Scan
# count     22510.000000
# mean       6193.076455
# std       10214.507757
# min           0.000000
# 25%         194.000000
# 50%        1882.500000
# 75%        8539.750000
# max      110348.000000
# Name: recent_churn, dtype: float64
# 99.9% quantile: 90616.47900000121

# %% [markdown]
# ## Check Distribution of Code Activity Keywords
#
# (todo, fixme, try/except/raise)

# %%
print("## 17. Keyword Column Distributions")
kw_cols = ["todo", "fixme", "try", "except", "raise"]

print(df[kw_cols].describe().T.to_markdown())
# Out:
# ## 17. Keyword Column Distributions
# |        |   count |      mean |       std |   min |   25% |   50% |   75% |   max |
# |:-------|--------:|----------:|----------:|------:|------:|------:|------:|------:|
# | todo   |   22510 | 0.132474  |  0.643505 |     0 |     0 |     0 |     0 |    26 |
# | fixme  |   22510 | 0.0137272 |  0.228647 |     0 |     0 |     0 |     0 |    17 |
# | try    |   22510 | 1.15806   | 12.6487   |     0 |     0 |     0 |     0 |   660 |
# | except |   22510 | 1.58992   |  8.20646  |     0 |     0 |     0 |     0 |   128 |
# | raise  |   22510 | 1.57606   |  6.64527  |     0 |     0 |     0 |     1 |   213 |
